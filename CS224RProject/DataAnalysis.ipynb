# %%
import torch
import torch.nn as nn
import random
import numpy as np

# %%
import matplotlib
from matplotlib import pyplot as plt
def plot():
    scores = np.loadtxt("score_history.txt")
    best_squares = np.loadtxt("best_square_history.txt")
    moves = np.loadtxt("move_history.txt")
    x_axis = np.arange(len(moves))
    
    plt.clf()
    plt.plot(x_axis, scores)
    plt.title("SCORE HISTORY OVER RUNS")
    plt.show()
    plt.clf()
    
    plt.clf()
    plt.plot(x_axis, best_squares)
    plt.title("BEST SQUARE REACHED HISTORY OVER RUNS")
    plt.show()
    plt.clf()
    
    plt.clf()
    plt.plot(x_axis, moves)
    plt.title("MOVES COMPLETED HISTORY OVER RUNS")
    plt.show()
    plt.clf()
    
plot()

# %%
import torch
import torch.nn as nn
import random
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

valid_move_rate = np.loadtxt("valid_move_rate.txt")
x_axis = np.arange(len(valid_move_rate))
plt.clf()
plt.plot(x_axis, valid_move_rate)
plt.show()
plt.clf()

losses = np.loadtxt("avg_losses.txt")[10:]
x_axis = np.arange(len(losses))
plt.clf()
plt.plot(x_axis, losses)
plt.show()
plt.clf()

action_freq = np.loadtxt("action_freq.txt")
x_axis = np.arange(len(action_freq))
plt.clf()
plt.plot(x_axis, action_freq)
plt.show()
plt.clf()

total_moves = np.loadtxt("total_moves.txt")
x_axis = np.arange(len(total_moves))
plt.clf()
plt.plot(x_axis, total_moves)
plt.show()
plt.clf()

total_score = np.loadtxt("total_score.txt")
x_axis = np.arange(len(total_score))
plt.clf()
plt.plot(x_axis, total_score)
plt.show()
plt.clf()

highest_tile = np.loadtxt("highest_tile.txt")
x_axis = np.arange(len(highest_tile))
plt.clf()
plt.plot(x_axis, highest_tile)
plt.show()
plt.clf()

# %%
import torch
import torch.nn as nn
import random
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

avg_loss_pure = np.loadtxt("avg_loss_pure.txt")[:]
x_axis = np.arange(len(avg_loss_pure))
plt.clf()
plt.plot(x_axis, avg_loss_pure)
plt.show()
plt.clf()

avg_acc_pure = np.loadtxt("avg_acc_pure.txt")
x_axis = np.arange(len(avg_acc_pure))
plt.clf()
plt.plot(x_axis, avg_acc_pure)
plt.show()
plt.clf()
