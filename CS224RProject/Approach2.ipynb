# %%
import torch
import torch.nn as nn
import random
import numpy as np

TOTAL_SQUARES = 16
TOTAL_OPTIONS = 20
TOTAL_ACTIONS = 4
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.random.manual_seed(SEED)
torch.manual_seed(SEED)

# %%
class State2048:
    def __init__(self,version):
        self.version = version
        if self.version == "Log":
            self.base = 1
        elif self.version == "Reg":
            self.base = 2
        else:
            print("VERSION MUST BE EITHER 'REG' OR 'LOG'")
    
    def initialize_state(self):
        state = np.zeros((4,4))
        check = self.sample_n_locations_in_place(state, 2)
        assert np.sum(state != 0) == 2
        assert check
        return state
    
    def gen_new_number(self):
        z = random.uniform(0,1)
        if z > 0.1:
            return self.base
        else:
            return self.increment_number(self.base)
        
    def increment_number(self, num):
        if self.version == "Reg":
            return num * 2
        elif self.version == "Log":
            return num + 1
        else:
            print("VERSION MUST BE EITHER 'REG' OR 'LOG'")
        
    def move_by_action(self, input_state: np.ndarray, action: int):
        curr_state = np.copy(input_state)
        done = [[0 for _ in range(4)] for _ in range(4)]
        combines, combined_amt = 0, 0
        if action == 0:
            for c in range(4):
                for r in range(1,4):
                    num = curr_state[r,c]
                    if num == 0: continue
                    found = -1
                    for j in range(r-1,-1,-1):
                        if curr_state[j,c] != 0:
                            found = j
                            break
                    if found < 0 or curr_state[found,c] != num or done[found][c]:
                        curr_state[r,c] = 0
                        curr_state[found+1,c] = num
                    else:
                        curr_state[r,c] = 0
                        curr_state[found,c] = self.increment_number(curr_state[found,c])
                        combined_amt += curr_state[found,c]
                        combines += 1
                        done[found][c] = 1
        elif action == 1:
            for r in range(4):
                for c in range(2,-1,-1):
                    num = curr_state[r,c]
                    if num == 0: continue
                    found = 4
                    for j in range(c+1,4):
                        if curr_state[r,j] != 0:
                            found = j
                            break
                    if found > 3 or curr_state[r,found] != num or done[r][found]:
                        curr_state[r,c] = 0
                        curr_state[r,found-1] = num
                    else:
                        curr_state[r,c] = 0
                        curr_state[r,found] = self.increment_number(curr_state[r,found])
                        combined_amt += curr_state[found,c]
                        combines += 1
                        done[r][found] = 1
        elif action == 2:
            for c in range(4):
                for r in range(2,-1,-1):
                    num = curr_state[r,c]
                    if num == 0: continue
                    found = 4
                    for j in range(r+1,4):
                        if curr_state[j,c] != 0:
                            found = j
                            break
                    if found > 3 or curr_state[found,c] != num or done[found][c]:
                        curr_state[r,c] = 0
                        curr_state[found-1,c] = num
                    else:
                        curr_state[r,c] = 0
                        curr_state[found,c] = self.increment_number(curr_state[found,c])
                        combined_amt += curr_state[found,c]
                        combines += 1
                        done[found][c] = 1
        elif action == 3:
            for r in range(4):
                for c in range(1,4):
                    num = curr_state[r,c]
                    if num == 0: continue
                    found = -1
                    for j in range(c-1,-1,-1):
                        if curr_state[r,j] != 0:
                            found = j
                            break
                    if found < 0 or curr_state[r,found] != num or done[r][found]:
                        curr_state[r,c] = 0
                        curr_state[r,found+1] = num
                    else:
                        curr_state[r,c] = 0
                        curr_state[r,found] = self.increment_number(curr_state[r,found])
                        combined_amt += curr_state[found,c]
                        combines += 1
                        done[r][found] = 1
        else:
              print("ERROR INCORRECT INPUT ACTION")
        
        return curr_state, combines, combined_amt
    
    def transition(self, input_state, action: int):
        if not(action in self.possible_actions(input_state)):
            return input_state, True, False
        
        new_state, combined_count, combined_amt = self.move_by_action(input_state, action)
        if not(self.check_move_is_possible(new_state)):
            return new_state, False, True
        else:            
            prev = np.sum(new_state != 0)
            check = self.sample_n_locations_in_place(new_state, 1)
            assert prev == 16 or prev + 1 == np.sum(new_state != 0)
            assert check
            return new_state, True, True
        
    def check_move_is_possible(self, state):
        for r in range(4):
            for c in range(4):
                if state[r][c] == 0:
                    return True
                if r+1 < 4 and state[r+1][c] == state[r][c]:
                    return True
                if c+1 < 4 and state[r][c+1] == state[r][c]:
                    return True
        return False
    
    def used_spots(self, state):
        return np.sum(state != 0)
    
    def state_score(self, state, not_term, valid_move):
        if not(valid_move):
            return -20
        elif not(not_term):
            return -10
        else:
            count = np.sum(state != 0)
            s = np.sum(state)
            avg = s/count
            return avg
    
    def check_action_is_possible(self, state, action):
        if action == 0:
            for r in range(1,4):
                for c in range(4):
                    if state[r,c] != 0 and (state[r-1,c] == state[r,c] or state[r-1,c] == 0): return True
        elif action == 1:
            for r in range(4):
                for c in range(3):
                    if state[r,c] != 0 and (state[r,c+1] == state[r,c] or state[r,c+1] == 0): return True
        elif action == 2:
            for r in range(3):
                for c in range(4):
                    if state[r,c] != 0 and (state[r+1,c] == state[r,c] or state[r+1,c] == 0): return True
        elif action == 3:
            for r in range(4):
                for c in range(1,4):
                    if state[r,c] != 0 and (state[r,c-1] == state[r,c] or state[r,c-1] == 0): return True
        else:
            print("ERROR INCORRECT INPUT ACTION")
        return False
        
    def sample_n_locations_in_place(self, input_state, sample_count: int):
        locations = [(i,j) for i in range(4) for j in range(4) if input_state[i,j] == 0]
        if len(locations) == 0: return False
        for sample_r, sample_c in random.sample(locations, sample_count):
            input_state[sample_r,sample_c] = self.gen_new_number()
        return True
    
    def print_state(self, state):
        for r in range(4):
            for c in range(4):
                print(int(state[r][c]), end = " ")
            print()
    
    def possible_actions(self, state):
        return [i for i in range(4) if self.check_action_is_possible(state, i)]

# %%
#def conv_state(state_np):
#    return torch.flatten(torch.nn.functional.one_hot(torch.tensor(state_np).to(torch.int64), TOTAL_OPTIONS)).float()

class CONV_STATE:
    def __init__(self,version, ENV):
        self.version = version
        self.ENV = ENV
        allowed = ["base", "each", "alt", "old"]
        if not(version in allowed):
            print("ERROR: ILLEGAL CONV_STATE VERSION")
    def conv_state_old(self, state_np):
        return torch.flatten(torch.nn.functional.one_hot(torch.tensor(state_np).to(torch.int64), TOTAL_OPTIONS)).float()
    def conv_state_base(self, state_np):
        res = np.zeros((4, 4, 2, 3))
        for r in range(4):
            for c in range(4):
                curr, lr, lc = state_np[r][c], [], []
                for nr in range(4):
                    if nr == r: continue
                    if state_np[nr][c] == curr: lr.append(curr)
                    elif curr == 0 or state_np[nr][c] == 0: lr.append(0)
                    else: lr.append(-max(curr, state_np[nr][c]))
                for nc in range(4):
                    if nc == c: continue
                    if state_np[r][nc] == curr: lc.append(curr)
                    elif curr ==0 or state_np[r][nc] == 0: lc.append(0)
                    else: lc.append(-max(curr, state_np[r][nc]))
                for i, val in enumerate(lr):
                    res[r][c][0][i] = val
                for i, val in enumerate(lc):
                    res[r][c][1][i] = val
        input_tensor = torch.tensor(np.reshape(res, (-1,)))
        return input_tensor.float()

    def conv_state_each(self, state_np):
        res = np.reshape(state_np, (-1,))
        for a in range(4):
            state_next_np, non_term, valid_move = self.ENV.transition(state_np, a)
            if not(non_term) or not(valid_move):
                res = np.append(res, np.reshape(np.zeros(state_np.shape) - 1, (-1,)))
            else:
                res = np.append(res, np.reshape(state_np, (-1,)))
        input_tensor = torch.tensor(res).float()
        return input_tensor

    def conv_state_alt(self, state_np):
        res = np.zeros(4)
        for a in range(4):
            state_next_np, non_term, valid_move = self.ENV.transition(state_np, a)
            if not(non_term) or not(valid_move):
                res[a] = -1
            else:
                res[a] = 1
        input_tensor = torch.tensor(res).float()
        return input_tensor
    
    def convert(self, state_np):
        if self.version == 'base':
            return self.conv_state_base(state_np)
        elif self.version == 'each':
            return self.conv_state_each(state_np)
        elif self.version == 'alt':
            return self.conv_state_alt(state_np)
        elif self.version == 'old':
            return self.conv_state_old(state_np)
        else:
            print("ERROR: ILLEGAL CONV_STATE VERSION")

# %%
class DQN(nn.Module):
    def __init__(self, layers, learning_rate):
        super().__init__()
        self.model = nn.Sequential(*layers)
        self.optimizer = torch.optim.Adam(params = self.model.parameters(), lr = learning_rate)
        
    def forward(self, input_state):
        return self.model(input_state)
    
    def backprop_single(self, state, action, true_value):
        self.optimizer.zero_grad()
        computed_value = torch.sum(self.model(state) * torch.nn.functional.one_hot(torch.tensor(action).to(torch.int64), TOTAL_ACTIONS))
        mse_loss = (computed_value - true_value) ** 2
        mse_loss.backward()
        self.optimizer.step()
        return mse_loss.item()
        
    def backprop_batch(self, states, actions, true_values):
        self.optimizer.zero_grad()
        mask = torch.nn.functional.one_hot(actions.to(torch.int64), TOTAL_ACTIONS)
        values = torch.sum(self.model(states) * mask, dim = 1)
        mse_loss = torch.nn.functional.mse_loss(true_values.float(), values.float())
        mse_loss.backward()
        self.optimizer.step()
        return mse_loss.item()

# %%
epsilon = 1
GAMMA = 1
iterations = 1000
minibatch_size = 10
copy_model_freq = 10
start_lr = 1e-4
decrement_lr_freq = 100
model_save_freq = 100
decrement_eps_freq = 1
eps_decay_rate = 0.8

state_version = "old"
state_conv = {"old" : 4 * 4 * TOTAL_OPTIONS, "base" : 4 * 4 * 2 * 3, "each" : 4 * 4 * 5, "alt" : 4}

ENV = State2048("Log")
ENCODER = CONV_STATE(state_version, ENV)
IN_DIM = int(state_conv[state_version])
OUT_DIM = TOTAL_ACTIONS

layers = [nn.Linear(IN_DIM,128), nn.ReLU(), nn.Linear(128,64), nn.ReLU(), nn.Linear(64,32), nn.ReLU(), nn.Linear(32,16), nn.ReLU(), nn.Linear(16,8), nn.ReLU(), nn.Linear(8,OUT_DIM)]
DQNetwork = DQN(layers, start_lr)

score_history = np.array([])
best_square_history = np.array([])
move_history = np.array([])

D = []

def greedy_action(model, state):
    action_values = model(state)
    #print(action_values)
    #print()
    action = torch.argmax(action_values)
    return int(action), action_values[action]

def greedy_action_full(all_models, state):
    action_values = np.zeros(4)
    for action in range(4):
        action_values[action] = all_models[action](state)
    action = np.argmax(action_values)
    return int(action), action_values[action]

def buffer_train(D, sample_size, g, model):
    sample = random.sample(D, min(len(D),sample_size))
    loss = 0
    for s,a,r,s_next,n_t,v_m in sample:
        tv = r
        if n_t and v_m: tv += g * greedy_action(model, s_next)[1].item()
        loss += model.backprop_single(s, a, tv)
    avg_loss = loss/len(sample)
    return avg_loss

valid_move_rate = []
action_freq = np.zeros(4)
avg_losses = []
total_moves = []
total_score = []
highest_tile = []

D = []
#DD = [[] for _ in range(4)]
#counts = [[0,0] for _ in range(4)]

#state_np = ENV.initialize_state()

for iteration in range(1,iterations+1):
    moves = 0
    real_moves = 0
    valid_moves = 0
    non_term = True
    state_np = ENV.initialize_state()
    loss = 0
    trains = 0
    
    epsilon *= 0.8
    
    avg_loss = 0
    avg_loss_count= 0
    
    while non_term and moves < 100:
        #state = conv_state(state_np)
        #state = conv_state_each(state_np, ENV)
        state = ENCODER.convert(state_np)
        
        action = -1
        rand = False
        if random.uniform(0,1) <= epsilon:
            action = random.choice([0,1,2,3])
            rand = True
        else:
            action, predicted_action_value = greedy_action(DQNetwork, state)
        
        state_next_np, non_term, valid_move = ENV.transition(state_np, action)
        state_next = ENCODER.convert(state_next_np)
        reward = ENV.state_score(state_next_np, non_term, valid_move)
        
        if not(rand): real_moves += 1
        moves += 1
        valid_moves += (not(rand) and valid_move)
        if not(rand): action_freq[action] += 1
        
        D.append((state,action,reward,state_next,non_term,valid_move))
        
        #samples = random.sample(D, min(len(D),minibatch_size))
        #for s,a,r,s_next,poss_actions,not_term in samples:
        #    _, target_action_value = generate_greedy_action(TargetNetwork, s_next, poss_actions)
        #    target_val = r + GAMMA * target_action_value.item()
        #    if DOUBLE_DQN:
        #        if np.random.uniform(0,1) < 0.5:
        #            TargetNetwork.backprop_single(s, a, r + GAMMA * generate_greedy_action(TargetNetwork, s_next, poss_actions, True, False, DQNetwork).item())
        #        else:
        #            DQNetwork.backprop_single(s, a, r + GAMMA * generate_greedy_action(DQNetwork, s_next, poss_actions, True, False, DQNetwork).item())
        #    else:
        #        if not_term:
        #            DQNetwork.backprop_single(s, a, target_val)
        #        else:
        #            DQNetwork.backprop_single(s, a, r)
        
        
        _, target_action_value = greedy_action(DQNetwork, state_next)
        target_val = reward + GAMMA * target_action_value.item()
        if not(valid_move) or not(non_term): target_val = reward
        DQNetwork.backprop_single(state, action, target_val)
        poss = ENV.possible_actions(state_np)
        if len(poss) < 4:
            trains += 1
            for act in range(4):
                t1, t2, t3 = ENV.transition(state_np, act)
                rew = ENV.state_score(t1,t2,t3)
                D.append((state,act,rew,ENCODER.convert(t1),t2,t3))
                #tl = DQNetwork.backprop_single(state, act, rew)
                #loss += tl
        
        avg_loss += buffer_train(D, 64, 0.9, DQNetwork)
        avg_loss_count += 1
        
        state_np = state_next_np
        
    if iteration%100 == 0:
        print(iteration)
    avg_loss /= avg_loss_count
    #print(loss)
    #print(moves, real_moves, valid_moves)
    avg_losses.append(avg_loss)
    valid_move_rate.append(valid_moves/real_moves)
    total_moves.append(moves)
    total_score.append(np.sum(state_np))
    highest_tile.append(int(2 ** (np.amax(state_np))))
    np.savetxt("valid_move_rate.txt", np.array(valid_move_rate))
    np.savetxt("action_freq.txt", action_freq)
    np.savetxt("avg_losses.txt", np.array(avg_losses))
    np.savetxt("total_moves.txt", np.array(total_moves))
    np.savetxt("total_score.txt", np.array(total_score))
    np.savetxt("highest_tile.txt", np.array(highest_tile))
# Out:
# ------------------------------------
# NameErrorTraceback (most recent call last)
# Input In [1], in <cell line: 13>()
#      10 eps_decay_rate = 0.8
#      12 state_version = "old"
# ---> 13 state_conv = {"old" : 4 * 4 * TOTAL_OPTIONS, "base" : 4 * 4 * 2 * 3, "each" : 4 * 4 * 5, "alt" : 4}
#      15 ENV = State2048("Log")
#      16 ENCODER = CONV_STATE(state_version, ENV)
#
# NameError: name 'TOTAL_OPTIONS' is not defined

# %%
good, bad = 0, 0
for state, act, rew, v in D:
    if rew == 0: bad += 1
    else: good += 1
        
print(good, bad)
# Out:
# 70170 29830

# %%
avg_loss_pure = []
avg_acc_pure = []
DQNetwork = DQN(layers, 0.0001)
for iteration in range(1000):
    sample = random.sample(D, 64)
    avg_loss = 0
    acc = 0
    ppp = 0
    for s, a, r, poss in sample:
        r = r * 2 - 1
        action_values = DQNetwork(s)
        action = int(torch.argmax(action_values))
        acc += action in poss
        ppp += len(poss) > 0
        loss = DQNetwork.backprop_single(s,a,r)
        avg_loss += loss
    avg_loss /= len(sample)
    acc /= ppp
    avg_loss_pure.append(avg_loss)
    avg_acc_pure.append(acc)
    np.savetxt("avg_loss_pure.txt", np.array(avg_loss_pure))
    np.savetxt("avg_acc_pure.txt", np.array(avg_acc_pure))
# Out:
# ------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# Input In [230], in <cell line: 4>()
#      13     acc += action in poss
#      14     ppp += len(poss) > 0
# ---> 15     loss = DQNetwork.backprop_single(s,a,r)
#      16     avg_loss += loss
#      17 avg_loss /= len(sample)
#
# Input In [226], in DQN.backprop_single(self, state, action, true_value)
#      13 mse_loss = (computed_value - true_value) ** 2
#      14 mse_loss.backward()
# ---> 15 self.optimizer.step()
#      16 return mse_loss.item()
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py:140, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     138 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139 with torch.autograd.profiler.record_function(profile_name):
# --> 140     out = func(*args, **kwargs)
#     141     obj._optimizer_step_code()
#     142     return out
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py:23, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      21 try:
#      22     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 23     ret = func(self, *args, **kwargs)
#      24 finally:
#      25     torch.set_grad_enabled(prev_grad)
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:234, in Adam.step(self, closure, grad_scaler)
#     231                 raise RuntimeError('`requires_grad` is not supported for `step` in differentiable mode')
#     232             state_steps.append(state['step'])
# --> 234     adam(params_with_grad,
#     235          grads,
#     236          exp_avgs,
#     237          exp_avg_sqs,
#     238          max_exp_avg_sqs,
#     239          state_steps,
#     240          amsgrad=group['amsgrad'],
#     241          beta1=beta1,
#     242          beta2=beta2,
#     243          lr=group['lr'],
#     244          weight_decay=group['weight_decay'],
#     245          eps=group['eps'],
#     246          maximize=group['maximize'],
#     247          foreach=group['foreach'],
#     248          capturable=group['capturable'],
#     249          differentiable=group['differentiable'],
#     250          fused=group['fused'],
#     251          grad_scale=grad_scale,
#     252          found_inf=found_inf)
#     254 return loss
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:300, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     297 else:
#     298     func = _single_tensor_adam
# --> 300 func(params,
#     301      grads,
#     302      exp_avgs,
#     303      exp_avg_sqs,
#     304      max_exp_avg_sqs,
#     305      state_steps,
#     306      amsgrad=amsgrad,
#     307      beta1=beta1,
#     308      beta2=beta2,
#     309      lr=lr,
#     310      weight_decay=weight_decay,
#     311      eps=eps,
#     312      maximize=maximize,
#     313      capturable=capturable,
#     314      differentiable=differentiable,
#     315      grad_scale=grad_scale,
#     316      found_inf=found_inf)
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:364, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     362 # Decay the first and second moment running average coefficient
#     363 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# --> 364 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     366 if capturable or differentiable:
#     367     step = step_t
#
# KeyboardInterrupt:

# %%
for action in range(4):
    print("ACTION: ", action)
    for iteration in range(100):
        sample = random.sample(DD[action], 1000)
        avg_loss = 0
        for s, a, r in sample:
            loss = DQNFull[action].backprop_single(s,a,r)
            print(r, DQNFull[action](s))
            avg_loss += loss
        avg_loss /= len(sample)
    return avg_loss
# Out:
# ACTION:  0
# 0 tensor([-0.1967], grad_fn=<AddBackward0>)
# 1 tensor([-0.0881], grad_fn=<AddBackward0>)
# 1 tensor([0.1707], grad_fn=<AddBackward0>)
# 0 tensor([0.3784], grad_fn=<AddBackward0>)
# 1 tensor([0.6575], grad_fn=<AddBackward0>)
# 0 tensor([0.8113], grad_fn=<AddBackward0>)
# 1 tensor([0.9777], grad_fn=<AddBackward0>)
# 1 tensor([1.1309], grad_fn=<AddBackward0>)
# 0 tensor([1.1010], grad_fn=<AddBackward0>)
# 1 tensor([1.0592], grad_fn=<AddBackward0>)
# 0 tensor([0.8646], grad_fn=<AddBackward0>)
# 0 tensor([0.5615], grad_fn=<AddBackward0>)
# 1 tensor([0.3536], grad_fn=<AddBackward0>)
# 0 tensor([0.1140], grad_fn=<AddBackward0>)
# 1 tensor([0.0297], grad_fn=<AddBackward0>)
# 0 tensor([-0.0506], grad_fn=<AddBackward0>)
# 0 tensor([-0.1154], grad_fn=<AddBackward0>)
# 0 tensor([-0.1566], grad_fn=<AddBackward0>)
# 1 tensor([-0.0223], grad_fn=<AddBackward0>)
# 1 tensor([0.2500], grad_fn=<AddBackward0>)
# 0 tensor([0.4581], grad_fn=<AddBackward0>)
# 0 tensor([0.5775], grad_fn=<AddBackward0>)
# 0 tensor([0.5994], grad_fn=<AddBackward0>)
# 0 tensor([0.5303], grad_fn=<AddBackward0>)
# 1 tensor([0.5376], grad_fn=<AddBackward0>)
# 1 tensor([0.6129], grad_fn=<AddBackward0>)
# 0 tensor([0.5897], grad_fn=<AddBackward0>)
# 0 tensor([0.4813], grad_fn=<AddBackward0>)
# 1 tensor([0.4607], grad_fn=<AddBackward0>)
# 0 tensor([0.3738], grad_fn=<AddBackward0>)
# 1 tensor([0.3885], grad_fn=<AddBackward0>)
# 0 tensor([0.3441], grad_fn=<AddBackward0>)
# 1 tensor([0.4015], grad_fn=<AddBackward0>)
# 1 tensor([0.5421], grad_fn=<AddBackward0>)
# 0 tensor([0.5881], grad_fn=<AddBackward0>)
# 0 tensor([0.5421], grad_fn=<AddBackward0>)
# 1 tensor([0.5688], grad_fn=<AddBackward0>)
# 1 tensor([0.6569], grad_fn=<AddBackward0>)
# 0 tensor([0.6386], grad_fn=<AddBackward0>)
# 0 tensor([0.5271], grad_fn=<AddBackward0>)
# 0 tensor([0.3484], grad_fn=<AddBackward0>)
# 1 tensor([0.2845], grad_fn=<AddBackward0>)
# 1 tensor([0.3333], grad_fn=<AddBackward0>)
# 1 tensor([0.4764], grad_fn=<AddBackward0>)
# 1 tensor([0.6831], grad_fn=<AddBackward0>)
# 1 tensor([0.9163], grad_fn=<AddBackward0>)
# 0 tensor([0.9898], grad_fn=<AddBackward0>)
# 1 tensor([1.0576], grad_fn=<AddBackward0>)
# 1 tensor([1.1100], grad_fn=<AddBackward0>)
# 1 tensor([1.1408], grad_fn=<AddBackward0>)
# 1 tensor([1.1476], grad_fn=<AddBackward0>)
# 0 tensor([0.9829], grad_fn=<AddBackward0>)
# 1 tensor([0.8371], grad_fn=<AddBackward0>)
# 1 tensor([0.7301], grad_fn=<AddBackward0>)
# 0 tensor([0.5250], grad_fn=<AddBackward0>)
# 1 tensor([0.4112], grad_fn=<AddBackward0>)
# 1 tensor([0.3965], grad_fn=<AddBackward0>)
# 0 tensor([0.3242], grad_fn=<AddBackward0>)
# 0 tensor([0.2107], grad_fn=<AddBackward0>)
# 0 tensor([0.0771], grad_fn=<AddBackward0>)
# 0 tensor([-0.0547], grad_fn=<AddBackward0>)
# 0 tensor([-0.1653], grad_fn=<AddBackward0>)
# 0 tensor([-0.2401], grad_fn=<AddBackward0>)
# 0 tensor([-0.2716], grad_fn=<AddBackward0>)
# 0 tensor([-0.2593], grad_fn=<AddBackward0>)
# 1 tensor([-0.0601], grad_fn=<AddBackward0>)
# 1 tensor([0.2772], grad_fn=<AddBackward0>)
# 1 tensor([0.6886], grad_fn=<AddBackward0>)
# 1 tensor([1.1056], grad_fn=<AddBackward0>)
# 0 tensor([1.3156], grad_fn=<AddBackward0>)
# 1 tensor([1.4575], grad_fn=<AddBackward0>)
# 1 tensor([1.5171], grad_fn=<AddBackward0>)
# 0 tensor([1.3445], grad_fn=<AddBackward0>)
# 0 tensor([0.9895], grad_fn=<AddBackward0>)
# 1 tensor([0.6713], grad_fn=<AddBackward0>)
# 1 tensor([0.4339], grad_fn=<AddBackward0>)
# 1 tensor([0.3044], grad_fn=<AddBackward0>)
# 0 tensor([0.1425], grad_fn=<AddBackward0>)
# 0 tensor([-0.0246], grad_fn=<AddBackward0>)
# 0 tensor([-0.1713], grad_fn=<AddBackward0>)
# 0 tensor([-0.2779], grad_fn=<AddBackward0>)
# 1 tensor([-0.1833], grad_fn=<AddBackward0>)
# 1 tensor([0.0778], grad_fn=<AddBackward0>)
# 1 tensor([0.4499], grad_fn=<AddBackward0>)
# 1 tensor([0.8667], grad_fn=<AddBackward0>)
# 1 tensor([1.2618], grad_fn=<AddBackward0>)
# 1 tensor([1.5786], grad_fn=<AddBackward0>)
# 1 tensor([1.7775], grad_fn=<AddBackward0>)
# 0 tensor([1.6921], grad_fn=<AddBackward0>)
# 1 tensor([1.5125], grad_fn=<AddBackward0>)
# 0 tensor([1.1270], grad_fn=<AddBackward0>)
# 0 tensor([0.6136], grad_fn=<AddBackward0>)
# 0 tensor([0.0605], grad_fn=<AddBackward0>)
# 1 tensor([-0.2979], grad_fn=<AddBackward0>)
# 1 tensor([-0.4282], grad_fn=<AddBackward0>)
# 1 tensor([-0.3346], grad_fn=<AddBackward0>)
# 0 tensor([-0.2009], grad_fn=<AddBackward0>)
# 1 tensor([0.0963], grad_fn=<AddBackward0>)
# 0 tensor([0.3497], grad_fn=<AddBackward0>)
# 0 tensor([0.5263], grad_fn=<AddBackward0>)
# 1 tensor([0.7552], grad_fn=<AddBackward0>)
# 1 tensor([0.9974], grad_fn=<AddBackward0>)
# 0 tensor([1.0681], grad_fn=<AddBackward0>)
# 0 tensor([0.9741], grad_fn=<AddBackward0>)
# 0 tensor([0.7461], grad_fn=<AddBackward0>)
# 0 tensor([0.4308], grad_fn=<AddBackward0>)
# 1 tensor([0.2310], grad_fn=<AddBackward0>)
# 1 tensor([0.1645], grad_fn=<AddBackward0>)
# 0 tensor([0.0804], grad_fn=<AddBackward0>)
# 0 tensor([-0.0072], grad_fn=<AddBackward0>)
# 0 tensor([-0.0851], grad_fn=<AddBackward0>)
# 1 tensor([0.0050], grad_fn=<AddBackward0>)
# 0 tensor([0.0853], grad_fn=<AddBackward0>)
# 0 tensor([0.1451], grad_fn=<AddBackward0>)
# 1 tensor([0.3250], grad_fn=<AddBackward0>)
# 1 tensor([0.5866], grad_fn=<AddBackward0>)
# 1 tensor([0.8831], grad_fn=<AddBackward0>)
# 1 tensor([1.1673], grad_fn=<AddBackward0>)
# 1 tensor([1.3986], grad_fn=<AddBackward0>)
# 1 tensor([1.5478], grad_fn=<AddBackward0>)
# 1 tensor([1.6012], grad_fn=<AddBackward0>)
# 0 tensor([1.4129], grad_fn=<AddBackward0>)
# 1 tensor([1.1825], grad_fn=<AddBackward0>)
# 1 tensor([0.9481], grad_fn=<AddBackward0>)
# 1 tensor([0.7447], grad_fn=<AddBackward0>)
# 1 tensor([0.5993], grad_fn=<AddBackward0>)
# 1 tensor([0.5276], grad_fn=<AddBackward0>)
# 1 tensor([0.5329], grad_fn=<AddBackward0>)
# 1 tensor([0.6067], grad_fn=<AddBackward0>)
# 0 tensor([0.5835], grad_fn=<AddBackward0>)
# 1 tensor([0.6242], grad_fn=<AddBackward0>)
# 1 tensor([0.7164], grad_fn=<AddBackward0>)
# 1 tensor([0.8414], grad_fn=<AddBackward0>)
# 0 tensor([0.8294], grad_fn=<AddBackward0>)
# 1 tensor([0.8438], grad_fn=<AddBackward0>)
# 1 tensor([0.8800], grad_fn=<AddBackward0>)
# 0 tensor([0.7821], grad_fn=<AddBackward0>)
# 1 tensor([0.7263], grad_fn=<AddBackward0>)
# 1 tensor([0.7167], grad_fn=<AddBackward0>)
# 0 tensor([0.6017], grad_fn=<AddBackward0>)
# 0 tensor([0.4091], grad_fn=<AddBackward0>)
# 0 tensor([0.1750], grad_fn=<AddBackward0>)
# 1 tensor([0.0867], grad_fn=<AddBackward0>)
# 1 tensor([0.1425], grad_fn=<AddBackward0>)
# 1 tensor([0.3198], grad_fn=<AddBackward0>)
# 1 tensor([0.5801], grad_fn=<AddBackward0>)
# 1 tensor([0.8767], grad_fn=<AddBackward0>)
# 0 tensor([1.0137], grad_fn=<AddBackward0>)
# 0 tensor([0.9868], grad_fn=<AddBackward0>)
# 0 tensor([0.8166], grad_fn=<AddBackward0>)
# 1 tensor([0.6905], grad_fn=<AddBackward0>)
# 0 tensor([0.4749], grad_fn=<AddBackward0>)
# 1 tensor([0.3584], grad_fn=<AddBackward0>)
# 1 tensor([0.3487], grad_fn=<AddBackward0>)
# 1 tensor([0.4363], grad_fn=<AddBackward0>)
# 1 tensor([0.5986], grad_fn=<AddBackward0>)
# 1 tensor([0.8043], grad_fn=<AddBackward0>)
# 0 tensor([0.8702], grad_fn=<AddBackward0>)
# 0 tensor([0.8006], grad_fn=<AddBackward0>)
# 0 tensor([0.6196], grad_fn=<AddBackward0>)
# 1 tensor([0.5129], grad_fn=<AddBackward0>)
# 1 tensor([0.4890], grad_fn=<AddBackward0>)
# 1 tensor([0.5432], grad_fn=<AddBackward0>)
# 0 tensor([0.5115], grad_fn=<AddBackward0>)
# 1 tensor([0.5553], grad_fn=<AddBackward0>)
# 1 tensor([0.6607], grad_fn=<AddBackward0>)
# 0 tensor([0.6577], grad_fn=<AddBackward0>)
# 1 tensor([0.7057], grad_fn=<AddBackward0>)
# 0 tensor([0.6442], grad_fn=<AddBackward0>)
# 0 tensor([0.4934], grad_fn=<AddBackward0>)
# 1 tensor([0.4327], grad_fn=<AddBackward0>)
# 1 tensor([0.4623], grad_fn=<AddBackward0>)
# 0 tensor([0.4203], grad_fn=<AddBackward0>)
# 0 tensor([0.3201], grad_fn=<AddBackward0>)
# 0 tensor([0.1824], grad_fn=<AddBackward0>)
# 0 tensor([0.0313], grad_fn=<AddBackward0>)
# 1 tensor([0.0392], grad_fn=<AddBackward0>)
# 1 tensor([0.1889], grad_fn=<AddBackward0>)
# 0 tensor([0.2956], grad_fn=<AddBackward0>)
# 1 tensor([0.4963], grad_fn=<AddBackward0>)
# 1 tensor([0.7517], grad_fn=<AddBackward0>)
# 0 tensor([0.8699], grad_fn=<AddBackward0>)
# 0 tensor([0.8472], grad_fn=<AddBackward0>)
# 0 tensor([0.7010], grad_fn=<AddBackward0>)
# 0 tensor([0.4654], grad_fn=<AddBackward0>)
# 0 tensor([0.1843], grad_fn=<AddBackward0>)
# 1 tensor([0.0523], grad_fn=<AddBackward0>)
# 0 tensor([-0.0742], grad_fn=<AddBackward0>)
# 1 tensor([-0.0287], grad_fn=<AddBackward0>)
# 0 tensor([0.0166], grad_fn=<AddBackward0>)
# 1 tensor([0.2032], grad_fn=<AddBackward0>)
# 0 tensor([0.3410], grad_fn=<AddBackward0>)
# 1 tensor([0.5629], grad_fn=<AddBackward0>)
# 1 tensor([0.8275], grad_fn=<AddBackward0>)
# 1 tensor([1.0914], grad_fn=<AddBackward0>)
# 1 tensor([1.3155], grad_fn=<AddBackward0>)
# 0 tensor([1.3216], grad_fn=<AddBackward0>)
# 1 tensor([1.2794], grad_fn=<AddBackward0>)
# 0 tensor([1.0518], grad_fn=<AddBackward0>)
# 0 tensor([0.6913], grad_fn=<AddBackward0>)
# 0 tensor([0.2644], grad_fn=<AddBackward0>)
# 0 tensor([-0.1591], grad_fn=<AddBackward0>)
# 1 tensor([-0.3683], grad_fn=<AddBackward0>)
# 0 tensor([-0.5021], grad_fn=<AddBackward0>)
# 1 tensor([-0.4002], grad_fn=<AddBackward0>)
# 1 tensor([-0.1021], grad_fn=<AddBackward0>)
# 1 tensor([0.3286], grad_fn=<AddBackward0>)
# 0 tensor([0.6678], grad_fn=<AddBackward0>)
# 1 tensor([1.0223], grad_fn=<AddBackward0>)
# 1 tensor([1.3382], grad_fn=<AddBackward0>)
# 0 tensor([1.4248], grad_fn=<AddBackward0>)
# 0 tensor([1.2929], grad_fn=<AddBackward0>)
# 0 tensor([0.9843], grad_fn=<AddBackward0>)
# 0 tensor([0.5621], grad_fn=<AddBackward0>)
# 0 tensor([0.0995], grad_fn=<AddBackward0>)
# 1 tensor([-0.1844], grad_fn=<AddBackward0>)
# 1 tensor([-0.2659], grad_fn=<AddBackward0>)
# 0 tensor([-0.3002], grad_fn=<AddBackward0>)
# 1 tensor([-0.1405], grad_fn=<AddBackward0>)
# 0 tensor([0.0239], grad_fn=<AddBackward0>)
# 0 tensor([0.1685], grad_fn=<AddBackward0>)
# 1 tensor([0.4205], grad_fn=<AddBackward0>)
# 1 tensor([0.7324], grad_fn=<AddBackward0>)
# 0 tensor([0.9057], grad_fn=<AddBackward0>)
# 0 tensor([0.9287], grad_fn=<AddBackward0>)
# 1 tensor([0.9599], grad_fn=<AddBackward0>)
# 0 tensor([0.8472], grad_fn=<AddBackward0>)
# 1 tensor([0.7681], grad_fn=<AddBackward0>)
# 1 tensor([0.7310], grad_fn=<AddBackward0>)
# 1 tensor([0.7370], grad_fn=<AddBackward0>)
# 1 tensor([0.7811], grad_fn=<AddBackward0>)
# 0 tensor([0.7061], grad_fn=<AddBackward0>)
# 1 tensor([0.6817], grad_fn=<AddBackward0>)
# 0 tensor([0.5595], grad_fn=<AddBackward0>)
# 1 tensor([0.5143], grad_fn=<AddBackward0>)
# 1 tensor([0.5451], grad_fn=<AddBackward0>)
# 0 tensor([0.4925], grad_fn=<AddBackward0>)
# 0 tensor([0.3728], grad_fn=<AddBackward0>)
# 0 tensor([0.2102], grad_fn=<AddBackward0>)
# 0 tensor([0.0328], grad_fn=<AddBackward0>)
# 1 tensor([0.0156], grad_fn=<AddBackward0>)
# 0 tensor([-0.0023], grad_fn=<AddBackward0>)
# 0 tensor([-0.0180], grad_fn=<AddBackward0>)
# 0 tensor([-0.0295], grad_fn=<AddBackward0>)
# 0 tensor([-0.0355], grad_fn=<AddBackward0>)
# 1 tensor([0.1116], grad_fn=<AddBackward0>)
# 0 tensor([0.2277], grad_fn=<AddBackward0>)
# 1 tensor([0.4459], grad_fn=<AddBackward0>)
# 1 tensor([0.7241], grad_fn=<AddBackward0>)
# 0 tensor([0.8676], grad_fn=<AddBackward0>)
# 1 tensor([1.0164], grad_fn=<AddBackward0>)
# 0 tensor([1.0005], grad_fn=<AddBackward0>)
# 1 tensor([0.9860], grad_fn=<AddBackward0>)
# 1 tensor([0.9751], grad_fn=<AddBackward0>)
# 0 tensor([0.8215], grad_fn=<AddBackward0>)
# 0 tensor([0.5622], grad_fn=<AddBackward0>)
# 1 tensor([0.3933], grad_fn=<AddBackward0>)
# 0 tensor([0.1832], grad_fn=<AddBackward0>)
# 1 tensor([0.1147], grad_fn=<AddBackward0>)
# 0 tensor([0.0360], grad_fn=<AddBackward0>)
# 1 tensor([0.1074], grad_fn=<AddBackward0>)
# 0 tensor([0.1558], grad_fn=<AddBackward0>)
# 1 tensor([0.3239], grad_fn=<AddBackward0>)
# 1 tensor([0.5749], grad_fn=<AddBackward0>)
# 0 tensor([0.7161], grad_fn=<AddBackward0>)
# 0 tensor([0.7374], grad_fn=<AddBackward0>)
# 1 tensor([0.7954], grad_fn=<AddBackward0>)
# 1 tensor([0.8779], grad_fn=<AddBackward0>)
# 1 tensor([0.9701], grad_fn=<AddBackward0>)
# 1 tensor([1.0576], grad_fn=<AddBackward0>)
# 0 tensor([0.9801], grad_fn=<AddBackward0>)
# 1 tensor([0.9133], grad_fn=<AddBackward0>)
# 0 tensor([0.7183], grad_fn=<AddBackward0>)
# 1 tensor([0.5843], grad_fn=<AddBackward0>)
# 0 tensor([0.3774], grad_fn=<AddBackward0>)
# 0 tensor([0.1353], grad_fn=<AddBackward0>)
# 1 tensor([0.0453], grad_fn=<AddBackward0>)
# 0 tensor([-0.0425], grad_fn=<AddBackward0>)
# 0 tensor([-0.1152], grad_fn=<AddBackward0>)
# 0 tensor([-0.1636], grad_fn=<AddBackward0>)
# 1 tensor([-0.0352], grad_fn=<AddBackward0>)
# 1 tensor([0.2333], grad_fn=<AddBackward0>)
# 0 tensor([0.4406], grad_fn=<AddBackward0>)
# 1 tensor([0.7099], grad_fn=<AddBackward0>)
# 0 tensor([0.8472], grad_fn=<AddBackward0>)
# 1 tensor([0.9935], grad_fn=<AddBackward0>)
# 1 tensor([1.1262], grad_fn=<AddBackward0>)
# 1 tensor([1.2270], grad_fn=<AddBackward0>)
# 1 tensor([1.2842], grad_fn=<AddBackward0>)
# 1 tensor([1.2935], grad_fn=<AddBackward0>)
# 1 tensor([1.2584], grad_fn=<AddBackward0>)
# 0 tensor([1.0405], grad_fn=<AddBackward0>)
# 1 tensor([0.8384], grad_fn=<AddBackward0>)
# 0 tensor([0.5323], grad_fn=<AddBackward0>)
# 0 tensor([0.1780], grad_fn=<AddBackward0>)
# 0 tensor([-0.1674], grad_fn=<AddBackward0>)
# 0 tensor([-0.4536], grad_fn=<AddBackward0>)
# 1 tensor([-0.4957], grad_fn=<AddBackward0>)
# 0 tensor([-0.4601], grad_fn=<AddBackward0>)
# 0 tensor([-0.3600], grad_fn=<AddBackward0>)
# 0 tensor([-0.2165], grad_fn=<AddBackward0>)
# 1 tensor([0.0924], grad_fn=<AddBackward0>)
# 1 tensor([0.5045], grad_fn=<AddBackward0>)
# 0 tensor([0.8009], grad_fn=<AddBackward0>)
# 0 tensor([0.9492], grad_fn=<AddBackward0>)
# 1 tensor([1.0902], grad_fn=<AddBackward0>)
# 0 tensor([1.0558], grad_fn=<AddBackward0>)
# 1 tensor([1.0166], grad_fn=<AddBackward0>)
# 1 tensor([0.9789], grad_fn=<AddBackward0>)
# 0 tensor([0.8001], grad_fn=<AddBackward0>)
# 0 tensor([0.5210], grad_fn=<AddBackward0>)
# 0 tensor([0.1926], grad_fn=<AddBackward0>)
# 0 tensor([-0.1315], grad_fn=<AddBackward0>)
# 1 tensor([-0.2557], grad_fn=<AddBackward0>)
# 0 tensor([-0.3297], grad_fn=<AddBackward0>)
# 0 tensor([-0.3476], grad_fn=<AddBackward0>)
# 0 tensor([-0.3122], grad_fn=<AddBackward0>)
# 1 tensor([-0.0864], grad_fn=<AddBackward0>)
# 0 tensor([0.1296], grad_fn=<AddBackward0>)
# 0 tensor([0.3050], grad_fn=<AddBackward0>)
# 1 tensor([0.5656], grad_fn=<AddBackward0>)
# 0 tensor([0.7165], grad_fn=<AddBackward0>)
# 1 tensor([0.8944], grad_fn=<AddBackward0>)
# 0 tensor([0.9220], grad_fn=<AddBackward0>)
# 0 tensor([0.8105], grad_fn=<AddBackward0>)
# 1 tensor([0.7382], grad_fn=<AddBackward0>)
# 0 tensor([0.5638], grad_fn=<AddBackward0>)
# 1 tensor([0.4714], grad_fn=<AddBackward0>)
# 1 tensor([0.4665], grad_fn=<AddBackward0>)
# 0 tensor([0.3930], grad_fn=<AddBackward0>)
# 0 tensor([0.2686], grad_fn=<AddBackward0>)
# 1 tensor([0.2650], grad_fn=<AddBackward0>)
# 1 tensor([0.3706], grad_fn=<AddBackward0>)
# 1 tensor([0.5588], grad_fn=<AddBackward0>)
# 0 tensor([0.6455], grad_fn=<AddBackward0>)
# 1 tensor([0.7761], grad_fn=<AddBackward0>)
# 1 tensor([0.9269], grad_fn=<AddBackward0>)
# 0 tensor([0.9251], grad_fn=<AddBackward0>)
# 1 tensor([0.9347], grad_fn=<AddBackward0>)
# 1 tensor([0.9530], grad_fn=<AddBackward0>)
# 0 tensor([0.8281], grad_fn=<AddBackward0>)
# 1 tensor([0.7412], grad_fn=<AddBackward0>)
# 0 tensor([0.5531], grad_fn=<AddBackward0>)
# 1 tensor([0.4500], grad_fn=<AddBackward0>)
# 1 tensor([0.4388], grad_fn=<AddBackward0>)
# 0 tensor([0.3636], grad_fn=<AddBackward0>)
# 1 tensor([0.3904], grad_fn=<AddBackward0>)
# 1 tensor([0.5050], grad_fn=<AddBackward0>)
# 0 tensor([0.5332], grad_fn=<AddBackward0>)
# 1 tensor([0.6279], grad_fn=<AddBackward0>)
# 1 tensor([0.7684], grad_fn=<AddBackward0>)
# 0 tensor([0.7807], grad_fn=<AddBackward0>)
# 1 tensor([0.8244], grad_fn=<AddBackward0>)
# 1 tensor([0.8899], grad_fn=<AddBackward0>)
# 0 tensor([0.8165], grad_fn=<AddBackward0>)
# 1 tensor([0.7777], grad_fn=<AddBackward0>)
# 1 tensor([0.7758], grad_fn=<AddBackward0>)
# 0 tensor([0.6588], grad_fn=<AddBackward0>)
# 0 tensor([0.4554], grad_fn=<AddBackward0>)
# 1 tensor([0.3534], grad_fn=<AddBackward0>)
# 0 tensor([0.2090], grad_fn=<AddBackward0>)
# 0 tensor([0.0478], grad_fn=<AddBackward0>)
# 1 tensor([0.0445], grad_fn=<AddBackward0>)
# 1 tensor([0.1837], grad_fn=<AddBackward0>)
# 1 tensor([0.4302], grad_fn=<AddBackward0>)
# 0 tensor([0.5882], grad_fn=<AddBackward0>)
# 0 tensor([0.6430], grad_fn=<AddBackward0>)
# 1 tensor([0.7454], grad_fn=<AddBackward0>)
# 0 tensor([0.7266], grad_fn=<AddBackward0>)
# 1 tensor([0.7504], grad_fn=<AddBackward0>)
# 1 tensor([0.8090], grad_fn=<AddBackward0>)
# 1 tensor([0.8902], grad_fn=<AddBackward0>)
# 1 tensor([0.9797], grad_fn=<AddBackward0>)
# 0 tensor([0.9143], grad_fn=<AddBackward0>)
# 0 tensor([0.7192], grad_fn=<AddBackward0>)
# 0 tensor([0.4366], grad_fn=<AddBackward0>)
# 1 tensor([0.2661], grad_fn=<AddBackward0>)
# 0 tensor([0.0730], grad_fn=<AddBackward0>)
# 0 tensor([-0.1118], grad_fn=<AddBackward0>)
# 1 tensor([-0.1124], grad_fn=<AddBackward0>)
# 0 tensor([-0.0962], grad_fn=<AddBackward0>)
# 1 tensor([0.0816], grad_fn=<AddBackward0>)
# 0 tensor([0.2295], grad_fn=<AddBackward0>)
# 1 tensor([0.4774], grad_fn=<AddBackward0>)
# 0 tensor([0.6294], grad_fn=<AddBackward0>)
# 0 tensor([0.6725], grad_fn=<AddBackward0>)
# 0 tensor([0.6110], grad_fn=<AddBackward0>)
# 1 tensor([0.6137], grad_fn=<AddBackward0>)
# 0 tensor([0.5246], grad_fn=<AddBackward0>)
# 0 tensor([0.3663], grad_fn=<AddBackward0>)
# 0 tensor([0.1691], grad_fn=<AddBackward0>)
# 1 tensor([0.1155], grad_fn=<AddBackward0>)
# 0 tensor([0.0500], grad_fn=<AddBackward0>)
# 1 tensor([0.1328], grad_fn=<AddBackward0>)
# 1 tensor([0.3364], grad_fn=<AddBackward0>)
# 0 tensor([0.4697], grad_fn=<AddBackward0>)
# 0 tensor([0.5196], grad_fn=<AddBackward0>)
# 1 tensor([0.6361], grad_fn=<AddBackward0>)
# 1 tensor([0.7954], grad_fn=<AddBackward0>)
# 0 tensor([0.8200], grad_fn=<AddBackward0>)
# 0 tensor([0.7199], grad_fn=<AddBackward0>)
# 1 tensor([0.6715], grad_fn=<AddBackward0>)
# 0 tensor([0.5278], grad_fn=<AddBackward0>)
# 1 tensor([0.4689], grad_fn=<AddBackward0>)
# 1 tensor([0.4952], grad_fn=<AddBackward0>)
# 0 tensor([0.4449], grad_fn=<AddBackward0>)
# 1 tensor([0.4825], grad_fn=<AddBackward0>)
# 0 tensor([0.4443], grad_fn=<AddBackward0>)
# 0 tensor([0.3435], grad_fn=<AddBackward0>)
# 0 tensor([0.2015], grad_fn=<AddBackward0>)
# 1 tensor([0.1930], grad_fn=<AddBackward0>)
# 0 tensor([0.1564], grad_fn=<AddBackward0>)
# 1 tensor([0.2497], grad_fn=<AddBackward0>)
# 1 tensor([0.4457], grad_fn=<AddBackward0>)
# 0 tensor([0.5555], grad_fn=<AddBackward0>)
# 1 tensor([0.7209], grad_fn=<AddBackward0>)
# 0 tensor([0.7619], grad_fn=<AddBackward0>)
# 1 tensor([0.8344], grad_fn=<AddBackward0>)
# 0 tensor([0.7750], grad_fn=<AddBackward0>)
# 0 tensor([0.6056], grad_fn=<AddBackward0>)
# 0 tensor([0.3626], grad_fn=<AddBackward0>)
# 0 tensor([0.0896], grad_fn=<AddBackward0>)
# 1 tensor([-0.0199], grad_fn=<AddBackward0>)
# 0 tensor([-0.1155], grad_fn=<AddBackward0>)
# 1 tensor([-0.0348], grad_fn=<AddBackward0>)
# 0 tensor([0.0431], grad_fn=<AddBackward0>)
# 1 tensor([0.2562], grad_fn=<AddBackward0>)
# 0 tensor([0.4097], grad_fn=<AddBackward0>)
# 1 tensor([0.6362], grad_fn=<AddBackward0>)
# 1 tensor([0.8945], grad_fn=<AddBackward0>)
# 1 tensor([1.1429], grad_fn=<AddBackward0>)
# 0 tensor([1.1953], grad_fn=<AddBackward0>)
# 0 tensor([1.0640], grad_fn=<AddBackward0>)
# 0 tensor([0.7871], grad_fn=<AddBackward0>)
# 1 tensor([0.5696], grad_fn=<AddBackward0>)
# 1 tensor([0.4380], grad_fn=<AddBackward0>)
# 1 tensor([0.4035], grad_fn=<AddBackward0>)
# 0 tensor([0.3122], grad_fn=<AddBackward0>)
# 1 tensor([0.3328], grad_fn=<AddBackward0>)
# 0 tensor([0.3015], grad_fn=<AddBackward0>)
# 1 tensor([0.3778], grad_fn=<AddBackward0>)
# 0 tensor([0.3900], grad_fn=<AddBackward0>)
# 0 tensor([0.3427], grad_fn=<AddBackward0>)
# 1 tensor([0.3984], grad_fn=<AddBackward0>)
# 0 tensor([0.3889], grad_fn=<AddBackward0>)
# 0 tensor([0.3222], grad_fn=<AddBackward0>)
# 1 tensor([0.3636], grad_fn=<AddBackward0>)
# 0 tensor([0.3464], grad_fn=<AddBackward0>)
# 1 tensor([0.4288], grad_fn=<AddBackward0>)
# 0 tensor([0.4388], grad_fn=<AddBackward0>)
# 1 tensor([0.5318], grad_fn=<AddBackward0>)
# 1 tensor([0.6857], grad_fn=<AddBackward0>)
# 1 tensor([0.8713], grad_fn=<AddBackward0>)
# 1 tensor([1.0578], grad_fn=<AddBackward0>)
# 1 tensor([1.2170], grad_fn=<AddBackward0>)
# 1 tensor([1.3278], grad_fn=<AddBackward0>)
# 0 tensor([1.2284], grad_fn=<AddBackward0>)
# 0 tensor([0.9552], grad_fn=<AddBackward0>)
# 1 tensor([0.7159], grad_fn=<AddBackward0>)
# 0 tensor([0.3933], grad_fn=<AddBackward0>)
# 0 tensor([0.0440], grad_fn=<AddBackward0>)
# 1 tensor([-0.1271], grad_fn=<AddBackward0>)
# 1 tensor([-0.1124], grad_fn=<AddBackward0>)
# 0 tensor([-0.0823], grad_fn=<AddBackward0>)
# 0 tensor([-0.0429], grad_fn=<AddBackward0>)
# 1 tensor([0.1486], grad_fn=<AddBackward0>)
# 1 tensor([0.4482], grad_fn=<AddBackward0>)
# 1 tensor([0.8005], grad_fn=<AddBackward0>)
# 1 tensor([1.1475], grad_fn=<AddBackward0>)
# 1 tensor([1.4379], grad_fn=<AddBackward0>)
# 0 tensor([1.4838], grad_fn=<AddBackward0>)
# 0 tensor([1.3038], grad_fn=<AddBackward0>)
# 1 tensor([1.0963], grad_fn=<AddBackward0>)
# 1 tensor([0.8952], grad_fn=<AddBackward0>)
# 0 tensor([0.5806], grad_fn=<AddBackward0>)
# 0 tensor([0.2108], grad_fn=<AddBackward0>)
# 0 tensor([-0.1537], grad_fn=<AddBackward0>)
# 1 tensor([-0.3093], grad_fn=<AddBackward0>)
# 1 tensor([-0.2541], grad_fn=<AddBackward0>)
# 1 tensor([-0.0178], grad_fn=<AddBackward0>)
# 0 tensor([0.1975], grad_fn=<AddBackward0>)
# 0 tensor([0.3620], grad_fn=<AddBackward0>)
# 0 tensor([0.4562], grad_fn=<AddBackward0>)
# 0 tensor([0.4730], grad_fn=<AddBackward0>)
# 1 tensor([0.5666], grad_fn=<AddBackward0>)
# 0 tensor([0.5665], grad_fn=<AddBackward0>)
# 1 tensor([0.6310], grad_fn=<AddBackward0>)
# 1 tensor([0.7441], grad_fn=<AddBackward0>)
# 1 tensor([0.8841], grad_fn=<AddBackward0>)
# 0 tensor([0.8782], grad_fn=<AddBackward0>)
# 0 tensor([0.7420], grad_fn=<AddBackward0>)
# 0 tensor([0.5087], grad_fn=<AddBackward0>)
# 0 tensor([0.2229], grad_fn=<AddBackward0>)
# 1 tensor([0.0815], grad_fn=<AddBackward0>)
# 1 tensor([0.0913], grad_fn=<AddBackward0>)
# 1 tensor([0.2354], grad_fn=<AddBackward0>)
# 1 tensor([0.4790], grad_fn=<AddBackward0>)
# 1 tensor([0.7759], grad_fn=<AddBackward0>)
# 1 tensor([1.0767], grad_fn=<AddBackward0>)
# 1 tensor([1.3360], grad_fn=<AddBackward0>)
# 0 tensor([1.3702], grad_fn=<AddBackward0>)
# 1 tensor([1.3458], grad_fn=<AddBackward0>)
# 1 tensor([1.2723], grad_fn=<AddBackward0>)
# 1 tensor([1.1655], grad_fn=<AddBackward0>)
# 0 tensor([0.8959], grad_fn=<AddBackward0>)
# 1 tensor([0.6687], grad_fn=<AddBackward0>)
# 0 tensor([0.3646], grad_fn=<AddBackward0>)
# 1 tensor([0.1855], grad_fn=<AddBackward0>)
# 0 tensor([-0.0034], grad_fn=<AddBackward0>)
# 1 tensor([-0.0238], grad_fn=<AddBackward0>)
# 0 tensor([-0.0386], grad_fn=<AddBackward0>)
# 1 tensor([0.1028], grad_fn=<AddBackward0>)
# 1 tensor([0.3636], grad_fn=<AddBackward0>)
# 1 tensor([0.6930], grad_fn=<AddBackward0>)
# 1 tensor([1.0354], grad_fn=<AddBackward0>)
# 1 tensor([1.3384], grad_fn=<AddBackward0>)
# 0 tensor([1.4116], grad_fn=<AddBackward0>)
# 0 tensor([1.2676], grad_fn=<AddBackward0>)
# 1 tensor([1.0981], grad_fn=<AddBackward0>)
# 1 tensor([0.9310], grad_fn=<AddBackward0>)
# 1 tensor([0.7907], grad_fn=<AddBackward0>)
# 1 tensor([0.6956], grad_fn=<AddBackward0>)
# 1 tensor([0.6553], grad_fn=<AddBackward0>)
# 0 tensor([0.5214], grad_fn=<AddBackward0>)
# 0 tensor([0.3233], grad_fn=<AddBackward0>)
# 0 tensor([0.0967], grad_fn=<AddBackward0>)
# 0 tensor([-0.1217], grad_fn=<AddBackward0>)
# 1 tensor([-0.1511], grad_fn=<AddBackward0>)
# 1 tensor([-0.0062], grad_fn=<AddBackward0>)
# 0 tensor([0.1252], grad_fn=<AddBackward0>)
# 0 tensor([0.2248], grad_fn=<AddBackward0>)
# 0 tensor([0.2811], grad_fn=<AddBackward0>)
# 1 tensor([0.4388], grad_fn=<AddBackward0>)
# 1 tensor([0.6644], grad_fn=<AddBackward0>)
# 0 tensor([0.7684], grad_fn=<AddBackward0>)
# 0 tensor([0.7476], grad_fn=<AddBackward0>)
# 1 tensor([0.7664], grad_fn=<AddBackward0>)
# 1 tensor([0.8182], grad_fn=<AddBackward0>)
# 1 tensor([0.8920], grad_fn=<AddBackward0>)
# 1 tensor([0.9745], grad_fn=<AddBackward0>)
# 0 tensor([0.9034], grad_fn=<AddBackward0>)
# 0 tensor([0.7047], grad_fn=<AddBackward0>)
# 1 tensor([0.5699], grad_fn=<AddBackward0>)
# 0 tensor([0.3635], grad_fn=<AddBackward0>)
# 1 tensor([0.2727], grad_fn=<AddBackward0>)
# 0 tensor([0.1502], grad_fn=<AddBackward0>)
# 0 tensor([0.0175], grad_fn=<AddBackward0>)
# 0 tensor([-0.1046], grad_fn=<AddBackward0>)
# 1 tensor([-0.0495], grad_fn=<AddBackward0>)
# 1 tensor([0.1566], grad_fn=<AddBackward0>)
# 0 tensor([0.3188], grad_fn=<AddBackward0>)
# 0 tensor([0.4173], grad_fn=<AddBackward0>)
# 1 tensor([0.5929], grad_fn=<AddBackward0>)
# 0 tensor([0.6624], grad_fn=<AddBackward0>)
# 1 tensor([0.7755], grad_fn=<AddBackward0>)
# 1 tensor([0.9108], grad_fn=<AddBackward0>)
# 0 tensor([0.8965], grad_fn=<AddBackward0>)
# 1 tensor([0.8991], grad_fn=<AddBackward0>)
# 0 tensor([0.7670], grad_fn=<AddBackward0>)
# 1 tensor([0.6830], grad_fn=<AddBackward0>)
# 1 tensor([0.6548], grad_fn=<AddBackward0>)
# 1 tensor([0.6810], grad_fn=<AddBackward0>)
# 1 tensor([0.7523], grad_fn=<AddBackward0>)
# 0 tensor([0.7039], grad_fn=<AddBackward0>)
# 0 tensor([0.5551], grad_fn=<AddBackward0>)
# 0 tensor([0.3380], grad_fn=<AddBackward0>)
# 0 tensor([0.0920], grad_fn=<AddBackward0>)
# 1 tensor([0.0066], grad_fn=<AddBackward0>)
# 1 tensor([0.0783], grad_fn=<AddBackward0>)
# 1 tensor([0.2805], grad_fn=<AddBackward0>)
# 1 tensor([0.5701], grad_fn=<AddBackward0>)
# 1 tensor([0.8951], grad_fn=<AddBackward0>)
# 1 tensor([1.2034], grad_fn=<AddBackward0>)
# 0 tensor([1.3007], grad_fn=<AddBackward0>)
# 0 tensor([1.1942], grad_fn=<AddBackward0>)
# 1 tensor([1.0692], grad_fn=<AddBackward0>)
# 1 tensor([0.9464], grad_fn=<AddBackward0>)
# 1 tensor([0.8438], grad_fn=<AddBackward0>)
# 0 tensor([0.6254], grad_fn=<AddBackward0>)
# 1 tensor([0.4848], grad_fn=<AddBackward0>)
# 0 tensor([0.2858], grad_fn=<AddBackward0>)
# 1 tensor([0.2134], grad_fn=<AddBackward0>)
# 0 tensor([0.1163], grad_fn=<AddBackward0>)
# 0 tensor([0.0115], grad_fn=<AddBackward0>)
# 0 tensor([-0.0846], grad_fn=<AddBackward0>)
# 1 tensor([-0.0088], grad_fn=<AddBackward0>)
# 1 tensor([0.2101], grad_fn=<AddBackward0>)
# 0 tensor([0.3758], grad_fn=<AddBackward0>)
# 0 tensor([0.4688], grad_fn=<AddBackward0>)
# 0 tensor([0.4824], grad_fn=<AddBackward0>)
# 0 tensor([0.4224], grad_fn=<AddBackward0>)
# 0 tensor([0.3052], grad_fn=<AddBackward0>)
# 0 tensor([0.1540], grad_fn=<AddBackward0>)
# 1 tensor([0.1445], grad_fn=<AddBackward0>)
# 1 tensor([0.2641], grad_fn=<AddBackward0>)
# 0 tensor([0.3322], grad_fn=<AddBackward0>)
# 0 tensor([0.3438], grad_fn=<AddBackward0>)
# 1 tensor([0.4525], grad_fn=<AddBackward0>)
# 0 tensor([0.4825], grad_fn=<AddBackward0>)
# 1 tensor([0.5871], grad_fn=<AddBackward0>)
# 1 tensor([0.7432], grad_fn=<AddBackward0>)
# 1 tensor([0.9222], grad_fn=<AddBackward0>)
# 0 tensor([0.9450], grad_fn=<AddBackward0>)
# 1 tensor([0.9738], grad_fn=<AddBackward0>)
# 1 tensor([1.0037], grad_fn=<AddBackward0>)
# 1 tensor([1.0300], grad_fn=<AddBackward0>)
# 1 tensor([1.0492], grad_fn=<AddBackward0>)
# 1 tensor([1.0591], grad_fn=<AddBackward0>)
# 0 tensor([0.9090], grad_fn=<AddBackward0>)
# 0 tensor([0.6375], grad_fn=<AddBackward0>)
# 0 tensor([0.2975], grad_fn=<AddBackward0>)
# 0 tensor([-0.0533], grad_fn=<AddBackward0>)
# 1 tensor([-0.2108], grad_fn=<AddBackward0>)
# 0 tensor([-0.3209], grad_fn=<AddBackward0>)
# 0 tensor([-0.3719], grad_fn=<AddBackward0>)
# 0 tensor([-0.3619], grad_fn=<AddBackward0>)
# 1 tensor([-0.1487], grad_fn=<AddBackward0>)
# 1 tensor([0.2151], grad_fn=<AddBackward0>)
# 1 tensor([0.6600], grad_fn=<AddBackward0>)
# 1 tensor([1.1116], grad_fn=<AddBackward0>)
# 1 tensor([1.5014], grad_fn=<AddBackward0>)
# 0 tensor([1.6269], grad_fn=<AddBackward0>)
# 1 tensor([1.6461], grad_fn=<AddBackward0>)
# 1 tensor([1.5666], grad_fn=<AddBackward0>)
# 0 tensor([1.2614], grad_fn=<AddBackward0>)
# 1 tensor([0.9475], grad_fn=<AddBackward0>)
# 1 tensor([0.6727], grad_fn=<AddBackward0>)
# 0 tensor([0.3249], grad_fn=<AddBackward0>)
# 1 tensor([0.1127], grad_fn=<AddBackward0>)
# 0 tensor([-0.0952], grad_fn=<AddBackward0>)
# 0 tensor([-0.2681], grad_fn=<AddBackward0>)
# 1 tensor([-0.2342], grad_fn=<AddBackward0>)
# 1 tensor([-0.0195], grad_fn=<AddBackward0>)
# 1 tensor([0.3256], grad_fn=<AddBackward0>)
# 1 tensor([0.7368], grad_fn=<AddBackward0>)
# 1 tensor([1.1463], grad_fn=<AddBackward0>)
# 1 tensor([1.4931], grad_fn=<AddBackward0>)
# 1 tensor([1.7317], grad_fn=<AddBackward0>)
# 0 tensor([1.6881], grad_fn=<AddBackward0>)
# 0 tensor([1.3983], grad_fn=<AddBackward0>)
# 1 tensor([1.0783], grad_fn=<AddBackward0>)
# 1 tensor([0.7785], grad_fn=<AddBackward0>)
# 0 tensor([0.3930], grad_fn=<AddBackward0>)
# 0 tensor([-0.0124], grad_fn=<AddBackward0>)
# 0 tensor([-0.3756], grad_fn=<AddBackward0>)
# 0 tensor([-0.6467], grad_fn=<AddBackward0>)
# 0 tensor([-0.7946], grad_fn=<AddBackward0>)
# 0 tensor([-0.8095], grad_fn=<AddBackward0>)
# 0 tensor([-0.7025], grad_fn=<AddBackward0>)
# 0 tensor([-0.5018], grad_fn=<AddBackward0>)
# 1 tensor([-0.0987], grad_fn=<AddBackward0>)
# 0 tensor([0.2789], grad_fn=<AddBackward0>)
# 0 tensor([0.5775], grad_fn=<AddBackward0>)
# 0 tensor([0.7605], grad_fn=<AddBackward0>)
# 0 tensor([0.8122], grad_fn=<AddBackward0>)
# 1 tensor([0.8867], grad_fn=<AddBackward0>)
# 1 tensor([0.9706], grad_fn=<AddBackward0>)
# 0 tensor([0.9018], grad_fn=<AddBackward0>)
# 0 tensor([0.7061], grad_fn=<AddBackward0>)
# 0 tensor([0.4251], grad_fn=<AddBackward0>)
# 0 tensor([0.1089], grad_fn=<AddBackward0>)
# 1 tensor([-0.0432], grad_fn=<AddBackward0>)
# 1 tensor([-0.0252], grad_fn=<AddBackward0>)
# 0 tensor([-0.0053], grad_fn=<AddBackward0>)
# 0 tensor([0.0135], grad_fn=<AddBackward0>)
# 0 tensor([0.0284], grad_fn=<AddBackward0>)
# 0 tensor([0.0375], grad_fn=<AddBackward0>)
# 1 tensor([0.1888], grad_fn=<AddBackward0>)
# 1 tensor([0.4455], grad_fn=<AddBackward0>)
# 1 tensor([0.7589], grad_fn=<AddBackward0>)
# 0 tensor([0.9282], grad_fn=<AddBackward0>)
# 1 tensor([1.0913], grad_fn=<AddBackward0>)
# 1 tensor([1.2246], grad_fn=<AddBackward0>)
# 0 tensor([1.1625], grad_fn=<AddBackward0>)
# 1 tensor([1.0824], grad_fn=<AddBackward0>)
# 0 tensor([0.8497], grad_fn=<AddBackward0>)
# 1 tensor([0.6625], grad_fn=<AddBackward0>)
# 0 tensor([0.3955], grad_fn=<AddBackward0>)
# 1 tensor([0.2451], grad_fn=<AddBackward0>)
# 1 tensor([0.2219], grad_fn=<AddBackward0>)
# 0 tensor([0.1680], grad_fn=<AddBackward0>)
# 0 tensor([0.0945], grad_fn=<AddBackward0>)
# 1 tensor([0.1629], grad_fn=<AddBackward0>)
# 1 tensor([0.3489], grad_fn=<AddBackward0>)
# 0 tensor([0.4645], grad_fn=<AddBackward0>)
# 0 tensor([0.4995], grad_fn=<AddBackward0>)
# 1 tensor([0.6054], grad_fn=<AddBackward0>)
# 0 tensor([0.6107], grad_fn=<AddBackward0>)
# 0 tensor([0.5246], grad_fn=<AddBackward0>)
# 0 tensor([0.3691], grad_fn=<AddBackward0>)
# 1 tensor([0.3229], grad_fn=<AddBackward0>)
# 1 tensor([0.3822], grad_fn=<AddBackward0>)
# 1 tensor([0.5274], grad_fn=<AddBackward0>)
# 1 tensor([0.7285], grad_fn=<AddBackward0>)
# 0 tensor([0.8010], grad_fn=<AddBackward0>)
# 0 tensor([0.7471], grad_fn=<AddBackward0>)
# 1 tensor([0.7362], grad_fn=<AddBackward0>)
# 1 tensor([0.7657], grad_fn=<AddBackward0>)
# 1 tensor([0.8271], grad_fn=<AddBackward0>)
# 0 tensor([0.7592], grad_fn=<AddBackward0>)
# 1 tensor([0.7339], grad_fn=<AddBackward0>)
# 1 tensor([0.7508], grad_fn=<AddBackward0>)
# 1 tensor([0.8032], grad_fn=<AddBackward0>)
# 1 tensor([0.8798], grad_fn=<AddBackward0>)
# 1 tensor([0.9666], grad_fn=<AddBackward0>)
# 1 tensor([1.0498], grad_fn=<AddBackward0>)
# 1 tensor([1.1173], grad_fn=<AddBackward0>)
# 1 tensor([1.1605], grad_fn=<AddBackward0>)
# 0 tensor([1.0260], grad_fn=<AddBackward0>)
# 1 tensor([0.9011], grad_fn=<AddBackward0>)
# 0 tensor([0.6540], grad_fn=<AddBackward0>)
# 0 tensor([0.3340], grad_fn=<AddBackward0>)
# 0 tensor([-0.0040], grad_fn=<AddBackward0>)
# 0 tensor([-0.3078], grad_fn=<AddBackward0>)
# 1 tensor([-0.3856], grad_fn=<AddBackward0>)
# 1 tensor([-0.2489], grad_fn=<AddBackward0>)
# 0 tensor([-0.0888], grad_fn=<AddBackward0>)
# 1 tensor([0.2175], grad_fn=<AddBackward0>)
# 0 tensor([0.4608], grad_fn=<AddBackward0>)
# 1 tensor([0.7602], grad_fn=<AddBackward0>)
# 0 tensor([0.9163], grad_fn=<AddBackward0>)
# 1 tensor([1.0694], grad_fn=<AddBackward0>)
# 1 tensor([1.1969], grad_fn=<AddBackward0>)
# 1 tensor([1.2822], grad_fn=<AddBackward0>)
# 1 tensor([1.3170], grad_fn=<AddBackward0>)
# 1 tensor([1.3009], grad_fn=<AddBackward0>)
# 1 tensor([1.2414], grad_fn=<AddBackward0>)
# 1 tensor([1.1518], grad_fn=<AddBackward0>)
# 1 tensor([1.0484], grad_fn=<AddBackward0>)
# 0 tensor([0.7986], grad_fn=<AddBackward0>)
# 1 tensor([0.6039], grad_fn=<AddBackward0>)
# 1 tensor([0.4878], grad_fn=<AddBackward0>)
# 0 tensor([0.3104], grad_fn=<AddBackward0>)
# 1 tensor([0.2538], grad_fn=<AddBackward0>)
# 1 tensor([0.3146], grad_fn=<AddBackward0>)
# 0 tensor([0.3222], grad_fn=<AddBackward0>)
# 1 tensor([0.4305], grad_fn=<AddBackward0>)
# 0 tensor([0.4636], grad_fn=<AddBackward0>)
# 0 tensor([0.4239], grad_fn=<AddBackward0>)
# 0 tensor([0.3247], grad_fn=<AddBackward0>)
# 1 tensor([0.3366], grad_fn=<AddBackward0>)
# 0 tensor([0.2968], grad_fn=<AddBackward0>)
# 1 tensor([0.3664], grad_fn=<AddBackward0>)
# 0 tensor([0.3741], grad_fn=<AddBackward0>)
# 0 tensor([0.3250], grad_fn=<AddBackward0>)
# 1 tensor([0.3820], grad_fn=<AddBackward0>)
# 1 tensor([0.5260], grad_fn=<AddBackward0>)
# 1 tensor([0.7267], grad_fn=<AddBackward0>)
# 0 tensor([0.7983], grad_fn=<AddBackward0>)
# 0 tensor([0.7431], grad_fn=<AddBackward0>)
# 0 tensor([0.5819], grad_fn=<AddBackward0>)
# 1 tensor([0.4996], grad_fn=<AddBackward0>)
# 1 tensor([0.5005], grad_fn=<AddBackward0>)
# 0 tensor([0.4262], grad_fn=<AddBackward0>)
# 0 tensor([0.2954], grad_fn=<AddBackward0>)
# 1 tensor([0.2834], grad_fn=<AddBackward0>)
# 1 tensor([0.3802], grad_fn=<AddBackward0>)
# 0 tensor([0.4102], grad_fn=<AddBackward0>)
# 1 tensor([0.5258], grad_fn=<AddBackward0>)
# 0 tensor([0.5509], grad_fn=<AddBackward0>)
# 0 tensor([0.4907], grad_fn=<AddBackward0>)
# 0 tensor([0.3628], grad_fn=<AddBackward0>)
# 1 tensor([0.3435], grad_fn=<AddBackward0>)
# 0 tensor([0.2744], grad_fn=<AddBackward0>)
# 1 tensor([0.3213], grad_fn=<AddBackward0>)
# 1 tensor([0.4655], grad_fn=<AddBackward0>)
# 1 tensor([0.6756], grad_fn=<AddBackward0>)
# 0 tensor([0.7632], grad_fn=<AddBackward0>)
# 0 tensor([0.7273], grad_fn=<AddBackward0>)
# 0 tensor([0.5857], grad_fn=<AddBackward0>)
# 0 tensor([0.3703], grad_fn=<AddBackward0>)
# 1 tensor([0.2710], grad_fn=<AddBackward0>)
# 1 tensor([0.2912], grad_fn=<AddBackward0>)
# 1 tensor([0.4159], grad_fn=<AddBackward0>)
# 1 tensor([0.6159], grad_fn=<AddBackward0>)
# 0 tensor([0.7033], grad_fn=<AddBackward0>)
# 1 tensor([0.8267], grad_fn=<AddBackward0>)
# 0 tensor([0.8134], grad_fn=<AddBackward0>)
# 0 tensor([0.6792], grad_fn=<AddBackward0>)
# 1 tensor([0.6067], grad_fn=<AddBackward0>)
# 0 tensor([0.4501], grad_fn=<AddBackward0>)
# 1 tensor([0.3919], grad_fn=<AddBackward0>)
# 1 tensor([0.4310], grad_fn=<AddBackward0>)
# 1 tensor([0.5517], grad_fn=<AddBackward0>)
# 0 tensor([0.5773], grad_fn=<AddBackward0>)
# 1 tensor([0.6641], grad_fn=<AddBackward0>)
# 1 tensor([0.7927], grad_fn=<AddBackward0>)
# 0 tensor([0.7891], grad_fn=<AddBackward0>)
# 0 tensor([0.6672], grad_fn=<AddBackward0>)
# 0 tensor([0.4571], grad_fn=<AddBackward0>)
# 0 tensor([0.1992], grad_fn=<AddBackward0>)
# 1 tensor([0.0876], grad_fn=<AddBackward0>)
# 0 tensor([-0.0261], grad_fn=<AddBackward0>)
# 0 tensor([-0.1245], grad_fn=<AddBackward0>)
# 1 tensor([-0.0438], grad_fn=<AddBackward0>)
# 1 tensor([0.1857], grad_fn=<AddBackward0>)
# 0 tensor([0.3644], grad_fn=<AddBackward0>)
# 0 tensor([0.4705], grad_fn=<AddBackward0>)
# 1 tensor([0.6456], grad_fn=<AddBackward0>)
# 0 tensor([0.7061], grad_fn=<AddBackward0>)
# 1 tensor([0.8048], grad_fn=<AddBackward0>)
# 0 tensor([0.7725], grad_fn=<AddBackward0>)
# 0 tensor([0.6272], grad_fn=<AddBackward0>)
# 0 tensor([0.4019], grad_fn=<AddBackward0>)
# 1 tensor([0.2892], grad_fn=<AddBackward0>)
# 0 tensor([0.1442], grad_fn=<AddBackward0>)
# 1 tensor([0.1426], grad_fn=<AddBackward0>)
# 1 tensor([0.2701], grad_fn=<AddBackward0>)
# 1 tensor([0.4947], grad_fn=<AddBackward0>)
# 1 tensor([0.7730], grad_fn=<AddBackward0>)
# 1 tensor([1.0577], grad_fn=<AddBackward0>)
# 1 tensor([1.3053], grad_fn=<AddBackward0>)
# 1 tensor([1.4823], grad_fn=<AddBackward0>)
# 0 tensor([1.4183], grad_fn=<AddBackward0>)
# 1 tensor([1.2978], grad_fn=<AddBackward0>)
# 0 tensor([0.9945], grad_fn=<AddBackward0>)
# 0 tensor([0.5724], grad_fn=<AddBackward0>)
# 1 tensor([0.2566], grad_fn=<AddBackward0>)
# 1 tensor([0.0840], grad_fn=<AddBackward0>)
# 1 tensor([0.0663], grad_fn=<AddBackward0>)
# 0 tensor([0.0404], grad_fn=<AddBackward0>)
# 1 tensor([0.1611], grad_fn=<AddBackward0>)
# 1 tensor([0.3956], grad_fn=<AddBackward0>)
# 1 tensor([0.6974], grad_fn=<AddBackward0>)
# 1 tensor([1.0145], grad_fn=<AddBackward0>)
# 1 tensor([1.2979], grad_fn=<AddBackward0>)
# 1 tensor([1.5083], grad_fn=<AddBackward0>)
# 0 tensor([1.4711], grad_fn=<AddBackward0>)
# 0 tensor([1.2175], grad_fn=<AddBackward0>)
# 1 tensor([0.9566], grad_fn=<AddBackward0>)
# 1 tensor([0.7282], grad_fn=<AddBackward0>)
# 0 tensor([0.4135], grad_fn=<AddBackward0>)
# 1 tensor([0.2182], grad_fn=<AddBackward0>)
# 1 tensor([0.1595], grad_fn=<AddBackward0>)
# 0 tensor([0.0828], grad_fn=<AddBackward0>)
# 1 tensor([0.1511], grad_fn=<AddBackward0>)
# 1 tensor([0.3397], grad_fn=<AddBackward0>)
# 1 tensor([0.6083], grad_fn=<AddBackward0>)
# 0 tensor([0.7590], grad_fn=<AddBackward0>)
# 1 tensor([0.9308], grad_fn=<AddBackward0>)
# 1 tensor([1.0958], grad_fn=<AddBackward0>)
# 0 tensor([1.0801], grad_fn=<AddBackward0>)
# 0 tensor([0.9044], grad_fn=<AddBackward0>)
# 0 tensor([0.6110], grad_fn=<AddBackward0>)
# 0 tensor([0.2555], grad_fn=<AddBackward0>)
# 1 tensor([0.0470], grad_fn=<AddBackward0>)
# 1 tensor([0.0019], grad_fn=<AddBackward0>)
# 0 tensor([-0.0390], grad_fn=<AddBackward0>)
# 0 tensor([-0.0700], grad_fn=<AddBackward0>)
# 1 tensor([0.0621], grad_fn=<AddBackward0>)
# 0 tensor([0.1718], grad_fn=<AddBackward0>)
# 1 tensor([0.3944], grad_fn=<AddBackward0>)
# 1 tensor([0.6853], grad_fn=<AddBackward0>)
# 1 tensor([0.9943], grad_fn=<AddBackward0>)
# 1 tensor([1.2734], grad_fn=<AddBackward0>)
# 0 tensor([1.3339], grad_fn=<AddBackward0>)
# 1 tensor([1.3384], grad_fn=<AddBackward0>)
# 0 tensor([1.1425], grad_fn=<AddBackward0>)
# 0 tensor([0.7960], grad_fn=<AddBackward0>)
# 1 tensor([0.5144], grad_fn=<AddBackward0>)
# 1 tensor([0.3334], grad_fn=<AddBackward0>)
# 0 tensor([0.1207], grad_fn=<AddBackward0>)
# 1 tensor([0.0606], grad_fn=<AddBackward0>)
# 0 tensor([-0.0026], grad_fn=<AddBackward0>)
# 0 tensor([-0.0591], grad_fn=<AddBackward0>)
# 0 tensor([-0.1011], grad_fn=<AddBackward0>)
# 0 tensor([-0.1239], grad_fn=<AddBackward0>)
# 0 tensor([-0.1258], grad_fn=<AddBackward0>)
# 0 tensor([-0.1087], grad_fn=<AddBackward0>)
# 0 tensor([-0.0770], grad_fn=<AddBackward0>)
# 0 tensor([-0.0369], grad_fn=<AddBackward0>)
# 0 tensor([0.0047], grad_fn=<AddBackward0>)
# 1 tensor([0.1913], grad_fn=<AddBackward0>)
# 1 tensor([0.4804], grad_fn=<AddBackward0>)
# 0 tensor([0.6686], grad_fn=<AddBackward0>)
# 0 tensor([0.7378], grad_fn=<AddBackward0>)
# 0 tensor([0.6895], grad_fn=<AddBackward0>)
# 1 tensor([0.6926], grad_fn=<AddBackward0>)
# 1 tensor([0.7414], grad_fn=<AddBackward0>)
# 1 tensor([0.8242], grad_fn=<AddBackward0>)
# 0 tensor([0.7751], grad_fn=<AddBackward0>)
# 0 tensor([0.6146], grad_fn=<AddBackward0>)
# 0 tensor([0.3780], grad_fn=<AddBackward0>)
# 0 tensor([0.1082], grad_fn=<AddBackward0>)
# 1 tensor([-0.0007], grad_fn=<AddBackward0>)
# 1 tensor([0.0513], grad_fn=<AddBackward0>)
# 1 tensor([0.2402], grad_fn=<AddBackward0>)
# 0 tensor([0.3743], grad_fn=<AddBackward0>)
# 0 tensor([0.4389], grad_fn=<AddBackward0>)
# 1 tensor([0.5812], grad_fn=<AddBackward0>)
# 0 tensor([0.6221], grad_fn=<AddBackward0>)
# 0 tensor([0.5656], grad_fn=<AddBackward0>)
# 1 tensor([0.5799], grad_fn=<AddBackward0>)
# 1 tensor([0.6559], grad_fn=<AddBackward0>)
# 0 tensor([0.6258], grad_fn=<AddBackward0>)
# 1 tensor([0.6549], grad_fn=<AddBackward0>)
# 1 tensor([0.7329], grad_fn=<AddBackward0>)
# 0 tensor([0.6930], grad_fn=<AddBackward0>)
# 1 tensor([0.7033], grad_fn=<AddBackward0>)
# 0 tensor([0.6069], grad_fn=<AddBackward0>)
# 1 tensor([0.5791], grad_fn=<AddBackward0>)
# 1 tensor([0.6174], grad_fn=<AddBackward0>)
# 0 tensor([0.5591], grad_fn=<AddBackward0>)
# 0 tensor([0.4225], grad_fn=<AddBackward0>)
# 1 tensor([0.3864], grad_fn=<AddBackward0>)
# 0 tensor([0.2958], grad_fn=<AddBackward0>)
# 1 tensor([0.3202], grad_fn=<AddBackward0>)
# 1 tensor([0.4443], grad_fn=<AddBackward0>)
# 1 tensor([0.6397], grad_fn=<AddBackward0>)
# 1 tensor([0.8698], grad_fn=<AddBackward0>)
# 0 tensor([0.9459], grad_fn=<AddBackward0>)
# 1 tensor([1.0227], grad_fn=<AddBackward0>)
# 1 tensor([1.0884], grad_fn=<AddBackward0>)
# 1 tensor([1.1342], grad_fn=<AddBackward0>)
# 0 tensor([1.0047], grad_fn=<AddBackward0>)
# 0 tensor([0.7371], grad_fn=<AddBackward0>)
# 1 tensor([0.5358], grad_fn=<AddBackward0>)
# 1 tensor([0.4244], grad_fn=<AddBackward0>)
# 1 tensor([0.4107], grad_fn=<AddBackward0>)
# 0 tensor([0.3366], grad_fn=<AddBackward0>)
# 1 tensor([0.3698], grad_fn=<AddBackward0>)
# 1 tensor([0.4945], grad_fn=<AddBackward0>)
# 1 tensor([0.6830], grad_fn=<AddBackward0>)
# 0 tensor([0.7497], grad_fn=<AddBackward0>)
# 1 tensor([0.8475], grad_fn=<AddBackward0>)
# 0 tensor([0.8078], grad_fn=<AddBackward0>)
# 1 tensor([0.8011], grad_fn=<AddBackward0>)
# 0 tensor([0.6743], grad_fn=<AddBackward0>)
# 0 tensor([0.4586], grad_fn=<AddBackward0>)
# 1 tensor([0.3461], grad_fn=<AddBackward0>)
# 1 tensor([0.3433], grad_fn=<AddBackward0>)
# 0 tensor([0.2891], grad_fn=<AddBackward0>)
# 0 tensor([0.1966], grad_fn=<AddBackward0>)
# 0 tensor([0.0837], grad_fn=<AddBackward0>)
# 0 tensor([-0.0305], grad_fn=<AddBackward0>)
# 1 tensor([0.0221], grad_fn=<AddBackward0>)
# 1 tensor([0.2169], grad_fn=<AddBackward0>)
# 0 tensor([0.3595], grad_fn=<AddBackward0>)
# 0 tensor([0.4337], grad_fn=<AddBackward0>)
# 0 tensor([0.4351], grad_fn=<AddBackward0>)
# 1 tensor([0.5215], grad_fn=<AddBackward0>)
# 0 tensor([0.5207], grad_fn=<AddBackward0>)
# 1 tensor([0.5922], grad_fn=<AddBackward0>)
# 0 tensor([0.5672], grad_fn=<AddBackward0>)
# 0 tensor([0.4591], grad_fn=<AddBackward0>)
# 1 tensor([0.4434], grad_fn=<AddBackward0>)
# 1 tensor([0.5134], grad_fn=<AddBackward0>)
# 1 tensor([0.6499], grad_fn=<AddBackward0>)
# 1 tensor([0.8258], grad_fn=<AddBackward0>)
# 0 tensor([0.8592], grad_fn=<AddBackward0>)
# 0 tensor([0.7595], grad_fn=<AddBackward0>)
# 0 tensor([0.5550], grad_fn=<AddBackward0>)
# 1 tensor([0.4382], grad_fn=<AddBackward0>)
# 1 tensor([0.4179], grad_fn=<AddBackward0>)
# 0 tensor([0.3365], grad_fn=<AddBackward0>)
# 0 tensor([0.2123], grad_fn=<AddBackward0>)
# 0 tensor([0.0684], grad_fn=<AddBackward0>)
# 1 tensor([0.0798], grad_fn=<AddBackward0>)
# 1 tensor([0.2291], grad_fn=<AddBackward0>)
# 1 tensor([0.4799], grad_fn=<AddBackward0>)
# 0 tensor([0.6332], grad_fn=<AddBackward0>)
# 0 tensor([0.6754], grad_fn=<AddBackward0>)
# 0 tensor([0.6114], grad_fn=<AddBackward0>)
# 0 tensor([0.4613], grad_fn=<AddBackward0>)
# 0 tensor([0.2565], grad_fn=<AddBackward0>)
# 0 tensor([0.0332], grad_fn=<AddBackward0>)
# 0 tensor([-0.1728], grad_fn=<AddBackward0>)
# 0 tensor([-0.3322], grad_fn=<AddBackward0>)
# 1 tensor([-0.2740], grad_fn=<AddBackward0>)
# 0 tensor([-0.1802], grad_fn=<AddBackward0>)
# 1 tensor([0.0825], grad_fn=<AddBackward0>)
# 1 tensor([0.4573], grad_fn=<AddBackward0>)
# 1 tensor([0.8766], grad_fn=<AddBackward0>)
# 0 tensor([1.1215], grad_fn=<AddBackward0>)
# 1 tensor([1.3237], grad_fn=<AddBackward0>)
# 1 tensor([1.4568], grad_fn=<AddBackward0>)
# 1 tensor([1.5076], grad_fn=<AddBackward0>)
# 1 tensor([1.4766], grad_fn=<AddBackward0>)
# 1 tensor([1.3766], grad_fn=<AddBackward0>)
# 1 tensor([1.2297], grad_fn=<AddBackward0>)
# 0 tensor([0.9118], grad_fn=<AddBackward0>)
# 1 tensor([0.6389], grad_fn=<AddBackward0>)
# 0 tensor([0.2967], grad_fn=<AddBackward0>)
# 1 tensor([0.0950], grad_fn=<AddBackward0>)
# 0 tensor([-0.1009], grad_fn=<AddBackward0>)
# 1 tensor([-0.1108], grad_fn=<AddBackward0>)
# 1 tensor([0.0480], grad_fn=<AddBackward0>)
# 1 tensor([0.3345], grad_fn=<AddBackward0>)
# 0 tensor([0.5419], grad_fn=<AddBackward0>)
# 1 tensor([0.7978], grad_fn=<AddBackward0>)
# 1 tensor([1.0587], grad_fn=<AddBackward0>)
# 0 tensor([1.1336], grad_fn=<AddBackward0>)
# 1 tensor([1.1809], grad_fn=<AddBackward0>)
# 1 tensor([1.1961], grad_fn=<AddBackward0>)
# 0 tensor([1.0293], grad_fn=<AddBackward0>)
# 1 tensor([0.8747], grad_fn=<AddBackward0>)
# 0 tensor([0.6037], grad_fn=<AddBackward0>)
# 0 tensor([0.2686], grad_fn=<AddBackward0>)
# 1 tensor([0.0774], grad_fn=<AddBackward0>)
# 1 tensor([0.0445], grad_fn=<AddBackward0>)
# 0.43477390311254843
# 0 tensor([0.0083], grad_fn=<AddBackward0>)
# 0 tensor([-0.0257], grad_fn=<AddBackward0>)
# 1 tensor([0.0986], grad_fn=<AddBackward0>)
# 1 tensor([0.3463], grad_fn=<AddBackward0>)
# 0 tensor([0.5171], grad_fn=<AddBackward0>)
# 0 tensor([0.5928], grad_fn=<AddBackward0>)
# 1 tensor([0.7224], grad_fn=<AddBackward0>)
# 1 tensor([0.8810], grad_fn=<AddBackward0>)
# 0 tensor([0.8908], grad_fn=<AddBackward0>)
# 0 tensor([0.7651], grad_fn=<AddBackward0>)
# 1 tensor([0.6874], grad_fn=<AddBackward0>)
# 0 tensor([0.5138], grad_fn=<AddBackward0>)
# 1 tensor([0.4308], grad_fn=<AddBackward0>)
# 0 tensor([0.2911], grad_fn=<AddBackward0>)
# 1 tensor([0.2724], grad_fn=<AddBackward0>)
# 1 tensor([0.3655], grad_fn=<AddBackward0>)
# 1 tensor([0.5450], grad_fn=<AddBackward0>)
# 0 tensor([0.6243], grad_fn=<AddBackward0>)
# 0 tensor([0.6014], grad_fn=<AddBackward0>)
# 0 tensor([0.4900], grad_fn=<AddBackward0>)
# 1 tensor([0.4667], grad_fn=<AddBackward0>)
# 0 tensor([0.3752], grad_fn=<AddBackward0>)
# 0 tensor([0.2361], grad_fn=<AddBackward0>)
# 1 tensor([0.2264], grad_fn=<AddBackward0>)
# 1 tensor([0.3346], grad_fn=<AddBackward0>)
# 0 tensor([0.3814], grad_fn=<AddBackward0>)
# 1 tensor([0.5171], grad_fn=<AddBackward0>)
# 0 tensor([0.5610], grad_fn=<AddBackward0>)
# 1 tensor([0.6669], grad_fn=<AddBackward0>)
# 0 tensor([0.6614], grad_fn=<AddBackward0>)
# 1 tensor([0.7077], grad_fn=<AddBackward0>)
# 0 tensor([0.6422], grad_fn=<AddBackward0>)
# 1 tensor([0.6375], grad_fn=<AddBackward0>)
# 0 tensor([0.5367], grad_fn=<AddBackward0>)
# 1 tensor([0.5161], grad_fn=<AddBackward0>)
# 1 tensor([0.5709], grad_fn=<AddBackward0>)
# 0 tensor([0.5337], grad_fn=<AddBackward0>)
# 0 tensor([0.4194], grad_fn=<AddBackward0>)
# 1 tensor([0.4045], grad_fn=<AddBackward0>)
# 0 tensor([0.3297], grad_fn=<AddBackward0>)
# 1 tensor([0.3640], grad_fn=<AddBackward0>)
# 1 tensor([0.4913], grad_fn=<AddBackward0>)
# 1 tensor([0.6830], grad_fn=<AddBackward0>)
# 1 tensor([0.9036], grad_fn=<AddBackward0>)
# 1 tensor([1.1169], grad_fn=<AddBackward0>)
# 0 tensor([1.1394], grad_fn=<AddBackward0>)
# 1 tensor([1.1385], grad_fn=<AddBackward0>)
# 0 tensor([0.9653], grad_fn=<AddBackward0>)
# 1 tensor([0.8145], grad_fn=<AddBackward0>)
# 0 tensor([0.5555], grad_fn=<AddBackward0>)
# 1 tensor([0.3897], grad_fn=<AddBackward0>)
# 1 tensor([0.3329], grad_fn=<AddBackward0>)
# 0 tensor([0.2313], grad_fn=<AddBackward0>)
# 0 tensor([0.1048], grad_fn=<AddBackward0>)
# 0 tensor([-0.0251], grad_fn=<AddBackward0>)
# 1 tensor([0.0136], grad_fn=<AddBackward0>)
# 0 tensor([0.0464], grad_fn=<AddBackward0>)
# 1 tensor([0.2205], grad_fn=<AddBackward0>)
# 1 tensor([0.4953], grad_fn=<AddBackward0>)
# 0 tensor([0.6676], grad_fn=<AddBackward0>)
# 0 tensor([0.7214], grad_fn=<AddBackward0>)
# 0 tensor([0.6605], grad_fn=<AddBackward0>)
# 1 tensor([0.6571], grad_fn=<AddBackward0>)
# 1 tensor([0.7061], grad_fn=<AddBackward0>)
# 1 tensor([0.7948], grad_fn=<AddBackward0>)
# 1 tensor([0.9059], grad_fn=<AddBackward0>)
# 0 tensor([0.8683], grad_fn=<AddBackward0>)
# 0 tensor([0.7027], grad_fn=<AddBackward0>)
# 1 tensor([0.5987], grad_fn=<AddBackward0>)
# 0 tensor([0.4142], grad_fn=<AddBackward0>)
# 1 tensor([0.3371], grad_fn=<AddBackward0>)
# 0 tensor([0.2165], grad_fn=<AddBackward0>)
# 0 tensor([0.0750], grad_fn=<AddBackward0>)
# 1 tensor([0.0882], grad_fn=<AddBackward0>)
# 1 tensor([0.2385], grad_fn=<AddBackward0>)
# 1 tensor([0.4894], grad_fn=<AddBackward0>)
# 1 tensor([0.7927], grad_fn=<AddBackward0>)
# 0 tensor([0.9453], grad_fn=<AddBackward0>)
# 0 tensor([0.9392], grad_fn=<AddBackward0>)
# 1 tensor([0.9429], grad_fn=<AddBackward0>)
# 1 tensor([0.9549], grad_fn=<AddBackward0>)
# 1 tensor([0.9726], grad_fn=<AddBackward0>)
# 1 tensor([0.9926], grad_fn=<AddBackward0>)
# 1 tensor([1.0118], grad_fn=<AddBackward0>)
# 1 tensor([1.0273], grad_fn=<AddBackward0>)
# 0 tensor([0.8850], grad_fn=<AddBackward0>)
# 0 tensor([0.6225], grad_fn=<AddBackward0>)
# 0 tensor([0.2916], grad_fn=<AddBackward0>)
# 1 tensor([0.1015], grad_fn=<AddBackward0>)
# 0 tensor([-0.0852], grad_fn=<AddBackward0>)
# 1 tensor([-0.0881], grad_fn=<AddBackward0>)
# 0 tensor([-0.0774], grad_fn=<AddBackward0>)
# 1 tensor([0.0959], grad_fn=<AddBackward0>)
# 0 tensor([0.2374], grad_fn=<AddBackward0>)
# 1 tensor([0.4806], grad_fn=<AddBackward0>)
# 1 tensor([0.7784], grad_fn=<AddBackward0>)
# 1 tensor([1.0802], grad_fn=<AddBackward0>)
# 0 tensor([1.1876], grad_fn=<AddBackward0>)
# 0 tensor([1.1039], grad_fn=<AddBackward0>)
# 0 tensor([0.8613], grad_fn=<AddBackward0>)
# 1 tensor([0.6639], grad_fn=<AddBackward0>)
# 1 tensor([0.5372], grad_fn=<AddBackward0>)
# 0 tensor([0.3416], grad_fn=<AddBackward0>)
# 1 tensor([0.2655], grad_fn=<AddBackward0>)
# 0 tensor([0.1566], grad_fn=<AddBackward0>)
# 1 tensor([0.1867], grad_fn=<AddBackward0>)
# 0 tensor([0.1854], grad_fn=<AddBackward0>)
# 1 tensor([0.3079], grad_fn=<AddBackward0>)
# 0 tensor([0.3715], grad_fn=<AddBackward0>)
# 1 tensor([0.5241], grad_fn=<AddBackward0>)
# 0 tensor([0.5819], grad_fn=<AddBackward0>)
# 0 tensor([0.5455], grad_fn=<AddBackward0>)
# ...
# 0 tensor([0.4119], grad_fn=<AddBackward0>)
# 1 tensor([0.3859], grad_fn=<AddBackward0>)
# 0 tensor([0.3042], grad_fn=<AddBackward0>)
# 1 tensor([0.3357], grad_fn=<AddBackward0>)
# 0 tensor([0.3134], grad_fn=<AddBackward0>)
# 0 tensor([0.2460], grad_fn=<AddBackward0>)
# 0 tensor([0.1481], grad_fn=<AddBackward0>)
# 1 tensor([0.1887], grad_fn=<AddBackward0>)
# 0 tensor([0.1967], grad_fn=<AddBackward0>)
# 0 tensor([0.1743], grad_fn=<AddBackward0>)
# 1 tensor([0.2788], grad_fn=<AddBackward0>)
# 1 tensor([0.4819], grad_fn=<AddBackward0>)
# 0 tensor([0.5919], grad_fn=<AddBackward0>)
# 1 tensor([0.7526], grad_fn=<AddBackward0>)
# 0 tensor([0.7835], grad_fn=<AddBackward0>)
# 0 tensor([0.6928], grad_fn=<AddBackward0>)
# 0 tensor([0.5065], grad_fn=<AddBackward0>)
# 0 tensor([0.2622], grad_fn=<AddBackward0>)
# 0 tensor([0.0025], grad_fn=<AddBackward0>)
# 0 tensor([-0.2316], grad_fn=<AddBackward0>)
# 1 tensor([-0.2559], grad_fn=<AddBackward0>)
# 1 tensor([-0.0882], grad_fn=<AddBackward0>)
# 1 tensor([0.2267], grad_fn=<AddBackward0>)
# 1 tensor([0.6267], grad_fn=<AddBackward0>)
# 0 tensor([0.8922], grad_fn=<AddBackward0>)
# 1 tensor([1.1475], grad_fn=<AddBackward0>)
# 1 tensor([1.3552], grad_fn=<AddBackward0>)
# 0 tensor([1.3375], grad_fn=<AddBackward0>)
# 1 tensor([1.2708], grad_fn=<AddBackward0>)
# 1 tensor([1.1698], grad_fn=<AddBackward0>)
# 0 tensor([0.9028], grad_fn=<AddBackward0>)
# 0 tensor([0.5266], grad_fn=<AddBackward0>)
# 1 tensor([0.2593], grad_fn=<AddBackward0>)
# 1 tensor([0.1303], grad_fn=<AddBackward0>)
# 0 tensor([-0.0055], grad_fn=<AddBackward0>)
# 0 tensor([-0.1269], grad_fn=<AddBackward0>)
# 1 tensor([-0.0664], grad_fn=<AddBackward0>)
# 0 tensor([-0.0019], grad_fn=<AddBackward0>)
# 0 tensor([0.0565], grad_fn=<AddBackward0>)
# 0 tensor([0.1005], grad_fn=<AddBackward0>)
# 0 tensor([0.1250], grad_fn=<AddBackward0>)
# 0 tensor([0.1282], grad_fn=<AddBackward0>)
# 0 tensor([0.1117], grad_fn=<AddBackward0>)
# 0 tensor([0.0799], grad_fn=<AddBackward0>)
# 1 tensor([0.1904], grad_fn=<AddBackward0>)
# 0 tensor([0.2610], grad_fn=<AddBackward0>)
# 0 tensor([0.2852], grad_fn=<AddBackward0>)
# 1 tensor([0.4150], grad_fn=<AddBackward0>)
# 0 tensor([0.4691], grad_fn=<AddBackward0>)
# 0 tensor([0.4468], grad_fn=<AddBackward0>)
# 1 tensor([0.5105], grad_fn=<AddBackward0>)
# 1 tensor([0.6419], grad_fn=<AddBackward0>)
# 0 tensor([0.6630], grad_fn=<AddBackward0>)
# 1 tensor([0.7330], grad_fn=<AddBackward0>)
# 0 tensor([0.6851], grad_fn=<AddBackward0>)
# 1 tensor([0.6896], grad_fn=<AddBackward0>)
# 1 tensor([0.7407], grad_fn=<AddBackward0>)
# 0 tensor([0.6745], grad_fn=<AddBackward0>)
# 0 tensor([0.5127], grad_fn=<AddBackward0>)
# 1 tensor([0.4409], grad_fn=<AddBackward0>)
# 1 tensor([0.4610], grad_fn=<AddBackward0>)
# 0 tensor([0.4093], grad_fn=<AddBackward0>)
# 0 tensor([0.3006], grad_fn=<AddBackward0>)
# 1 tensor([0.3088], grad_fn=<AddBackward0>)
# 0 tensor([0.2694], grad_fn=<AddBackward0>)
# 1 tensor([0.3447], grad_fn=<AddBackward0>)
# 1 tensor([0.5119], grad_fn=<AddBackward0>)
# 1 tensor([0.7364], grad_fn=<AddBackward0>)
# 1 tensor([0.9785], grad_fn=<AddBackward0>)
# 0 tensor([1.0479], grad_fn=<AddBackward0>)
# 0 tensor([0.9516], grad_fn=<AddBackward0>)
# 1 tensor([0.8721], grad_fn=<AddBackward0>)
# 0 tensor([0.6685], grad_fn=<AddBackward0>)
# 1 tensor([0.5354], grad_fn=<AddBackward0>)
# 0 tensor([0.3344], grad_fn=<AddBackward0>)
# 1 tensor([0.2545], grad_fn=<AddBackward0>)
# 1 tensor([0.2956], grad_fn=<AddBackward0>)
# 0 tensor([0.2877], grad_fn=<AddBackward0>)
# 0 tensor([0.2370], grad_fn=<AddBackward0>)
# 1 tensor([0.3071], grad_fn=<AddBackward0>)
# 0 tensor([0.3236], grad_fn=<AddBackward0>)
# 1 tensor([0.4412], grad_fn=<AddBackward0>)
# 0 tensor([0.4800], grad_fn=<AddBackward0>)
# 1 tensor([0.5939], grad_fn=<AddBackward0>)
# 1 tensor([0.7581], grad_fn=<AddBackward0>)
# 1 tensor([0.9427], grad_fn=<AddBackward0>)
# 1 tensor([1.1177], grad_fn=<AddBackward0>)
# 1 tensor([1.2573], grad_fn=<AddBackward0>)
# 0 tensor([1.1918], grad_fn=<AddBackward0>)
# 1 tensor([1.1037], grad_fn=<AddBackward0>)
# 1 tensor([1.0086], grad_fn=<AddBackward0>)
# 1 tensor([0.9217], grad_fn=<AddBackward0>)
# 0 tensor([0.7033], grad_fn=<AddBackward0>)
# 1 tensor([0.5519], grad_fn=<AddBackward0>)
# 0 tensor([0.3316], grad_fn=<AddBackward0>)
# 0 tensor([0.0828], grad_fn=<AddBackward0>)
# 0 tensor([-0.1539], grad_fn=<AddBackward0>)
# 0 tensor([-0.3435], grad_fn=<AddBackward0>)
# 1 tensor([-0.3096], grad_fn=<AddBackward0>)
# 1 tensor([-0.0802], grad_fn=<AddBackward0>)
# 0 tensor([0.1385], grad_fn=<AddBackward0>)
# 1 tensor([0.4661], grad_fn=<AddBackward0>)
# 1 tensor([0.8421], grad_fn=<AddBackward0>)
# 1 tensor([1.2047], grad_fn=<AddBackward0>)
# 0 tensor([1.3477], grad_fn=<AddBackward0>)
# 1 tensor([1.4237], grad_fn=<AddBackward0>)
# 0 tensor([1.2762], grad_fn=<AddBackward0>)
# 0 tensor([0.9504], grad_fn=<AddBackward0>)
# 1 tensor([0.6646], grad_fn=<AddBackward0>)
# 1 tensor([0.4580], grad_fn=<AddBackward0>)
# 0 tensor([0.2027], grad_fn=<AddBackward0>)
# 1 tensor([0.0938], grad_fn=<AddBackward0>)
# 0 tensor([-0.0186], grad_fn=<AddBackward0>)
# 0 tensor([-0.1169], grad_fn=<AddBackward0>)
# 1 tensor([-0.0361], grad_fn=<AddBackward0>)
# 0 tensor([0.0422], grad_fn=<AddBackward0>)
# 1 tensor([0.2577], grad_fn=<AddBackward0>)
# 1 tensor([0.5640], grad_fn=<AddBackward0>)
# 1 tensor([0.9059], grad_fn=<AddBackward0>)
# 1 tensor([1.2280], grad_fn=<AddBackward0>)
# 1 tensor([1.4834], grad_fn=<AddBackward0>)
# 0 tensor([1.4883], grad_fn=<AddBackward0>)
# 0 tensor([1.2679], grad_fn=<AddBackward0>)
# 1 tensor([1.0290], grad_fn=<AddBackward0>)
# 1 tensor([0.8094], grad_fn=<AddBackward0>)
# 1 tensor([0.6406], grad_fn=<AddBackward0>)
# 1 tensor([0.5429], grad_fn=<AddBackward0>)
# 1 tensor([0.5242], grad_fn=<AddBackward0>)
# 1 tensor([0.5794], grad_fn=<AddBackward0>)
# 1 tensor([0.6928], grad_fn=<AddBackward0>)
# 1 tensor([0.8414], grad_fn=<AddBackward0>)
# 1 tensor([0.9993], grad_fn=<AddBackward0>)
# 1 tensor([1.1415], grad_fn=<AddBackward0>)
# 0 tensor([1.0965], grad_fn=<AddBackward0>)
# 0 tensor([0.8900], grad_fn=<AddBackward0>)
# 1 tensor([0.7208], grad_fn=<AddBackward0>)
# 0 tensor([0.4593], grad_fn=<AddBackward0>)
# 1 tensor([0.3059], grad_fn=<AddBackward0>)
# 0 tensor([0.1214], grad_fn=<AddBackward0>)
# 0 tensor([-0.0632], grad_fn=<AddBackward0>)
# 0 tensor([-0.2198], grad_fn=<AddBackward0>)
# 1 tensor([-0.1758], grad_fn=<AddBackward0>)
# 0 tensor([-0.1095], grad_fn=<AddBackward0>)
# 1 tensor([0.1180], grad_fn=<AddBackward0>)
# 1 tensor([0.4562], grad_fn=<AddBackward0>)
# 0 tensor([0.6916], grad_fn=<AddBackward0>)
# 1 tensor([0.9502], grad_fn=<AddBackward0>)
# 0 tensor([1.0391], grad_fn=<AddBackward0>)
# 1 tensor([1.1131], grad_fn=<AddBackward0>)
# 1 tensor([1.1627], grad_fn=<AddBackward0>)
# 1 tensor([1.1826], grad_fn=<AddBackward0>)
# 1 tensor([1.1729], grad_fn=<AddBackward0>)
# 1 tensor([1.1379], grad_fn=<AddBackward0>)
# 0 tensor([0.9340], grad_fn=<AddBackward0>)
# 0 tensor([0.6090], grad_fn=<AddBackward0>)
# 0 tensor([0.2243], grad_fn=<AddBackward0>)
# 1 tensor([-0.0044], grad_fn=<AddBackward0>)
# 0 tensor([-0.2097], grad_fn=<AddBackward0>)
# 1 tensor([-0.2111], grad_fn=<AddBackward0>)
# 0 tensor([-0.1804], grad_fn=<AddBackward0>)
# 0 tensor([-0.1254], grad_fn=<AddBackward0>)
# 0 tensor([-0.0569], grad_fn=<AddBackward0>)
# 1 tensor([0.1648], grad_fn=<AddBackward0>)
# 1 tensor([0.4907], grad_fn=<AddBackward0>)
# 0 tensor([0.7098], grad_fn=<AddBackward0>)
# 0 tensor([0.7995], grad_fn=<AddBackward0>)
# 0 tensor([0.7591], grad_fn=<AddBackward0>)
# 1 tensor([0.7592], grad_fn=<AddBackward0>)
# 1 tensor([0.7959], grad_fn=<AddBackward0>)
# 1 tensor([0.8598], grad_fn=<AddBackward0>)
# 0 tensor([0.7870], grad_fn=<AddBackward0>)
# 1 tensor([0.7537], grad_fn=<AddBackward0>)
# 1 tensor([0.7612], grad_fn=<AddBackward0>)
# 0 tensor([0.6524], grad_fn=<AddBackward0>)
# 1 tensor([0.6072], grad_fn=<AddBackward0>)
# 0 tensor([0.4744], grad_fn=<AddBackward0>)
# 1 tensor([0.4346], grad_fn=<AddBackward0>)
# 0 tensor([0.3328], grad_fn=<AddBackward0>)
# 1 tensor([0.3425], grad_fn=<AddBackward0>)
# 1 tensor([0.4510], grad_fn=<AddBackward0>)
# 1 tensor([0.6320], grad_fn=<AddBackward0>)
# 0 tensor([0.6990], grad_fn=<AddBackward0>)
# 1 tensor([0.8050], grad_fn=<AddBackward0>)
# 0 tensor([0.7781], grad_fn=<AddBackward0>)
# 0 tensor([0.6358], grad_fn=<AddBackward0>)
# 0 tensor([0.4112], grad_fn=<AddBackward0>)
# 1 tensor([0.2985], grad_fn=<AddBackward0>)
# 1 tensor([0.3035], grad_fn=<AddBackward0>)
# 1 tensor([0.4138], grad_fn=<AddBackward0>)
# 0 tensor([0.4502], grad_fn=<AddBackward0>)
# 0 tensor([0.4146], grad_fn=<AddBackward0>)
# 1 tensor([0.4715], grad_fn=<AddBackward0>)
# 0 tensor([0.4511], grad_fn=<AddBackward0>)
# 0 tensor([0.3641], grad_fn=<AddBackward0>)
# 1 tensor([0.3825], grad_fn=<AddBackward0>)
# 1 tensor([0.4929], grad_fn=<AddBackward0>)
# 0 tensor([0.5174], grad_fn=<AddBackward0>)
# 1 tensor([0.6128], grad_fn=<AddBackward0>)
# 1 tensor([0.7576], grad_fn=<AddBackward0>)
# 1 tensor([0.9249], grad_fn=<AddBackward0>)
# 0 tensor([0.9346], grad_fn=<AddBackward0>)
# 0 tensor([0.8013], grad_fn=<AddBackward0>)
# 1 tensor([0.7115], grad_fn=<AddBackward0>)
# 0 tensor([0.5225], grad_fn=<AddBackward0>)
# 0 tensor([0.2728], grad_fn=<AddBackward0>)
# 0 tensor([0.0065], grad_fn=<AddBackward0>)
# 0 tensor([-0.2343], grad_fn=<AddBackward0>)
# 0 tensor([-0.4154], grad_fn=<AddBackward0>)
# 1 tensor([-0.3629], grad_fn=<AddBackward0>)
# 0 tensor([-0.2604], grad_fn=<AddBackward0>)
# 1 tensor([0.0232], grad_fn=<AddBackward0>)
# 0 tensor([0.2750], grad_fn=<AddBackward0>)
# 1 tensor([0.6118], grad_fn=<AddBackward0>)
# 0 tensor([0.8219], grad_fn=<AddBackward0>)
# 0 tensor([0.8861], grad_fn=<AddBackward0>)
# 0 tensor([0.8093], grad_fn=<AddBackward0>)
# 0 tensor([0.6173], grad_fn=<AddBackward0>)
# 1 tensor([0.5026], grad_fn=<AddBackward0>)
# 0 tensor([0.3229], grad_fn=<AddBackward0>)
# 1 tensor([0.2641], grad_fn=<AddBackward0>)
# 1 tensor([0.3230], grad_fn=<AddBackward0>)
# 1 tensor([0.4788], grad_fn=<AddBackward0>)
# 1 tensor([0.6982], grad_fn=<AddBackward0>)
# 0 tensor([0.7896], grad_fn=<AddBackward0>)
# 0 tensor([0.7519], grad_fn=<AddBackward0>)
# 0 tensor([0.6039], grad_fn=<AddBackward0>)
# 1 tensor([0.5307], grad_fn=<AddBackward0>)
# 0 tensor([0.3842], grad_fn=<AddBackward0>)
# 1 tensor([0.3460], grad_fn=<AddBackward0>)
# 1 tensor([0.4109], grad_fn=<AddBackward0>)
# 1 tensor([0.5589], grad_fn=<AddBackward0>)
# 0 tensor([0.6071], grad_fn=<AddBackward0>)
# 1 tensor([0.7103], grad_fn=<AddBackward0>)
# 1 tensor([0.8472], grad_fn=<AddBackward0>)
# 1 tensor([0.9938], grad_fn=<AddBackward0>)
# 1 tensor([1.1267], grad_fn=<AddBackward0>)
# 0 tensor([1.0749], grad_fn=<AddBackward0>)
# 0 tensor([0.8649], grad_fn=<AddBackward0>)
# 0 tensor([0.5446], grad_fn=<AddBackward0>)
# 0 tensor([0.1736], grad_fn=<AddBackward0>)
# 0 tensor([-0.1869], grad_fn=<AddBackward0>)
# 0 tensor([-0.4830], grad_fn=<AddBackward0>)
# 0 tensor([-0.6761], grad_fn=<AddBackward0>)
# 1 tensor([-0.5952], grad_fn=<AddBackward0>)
# 0 tensor([-0.4321], grad_fn=<AddBackward0>)
# 1 tensor([-0.0688], grad_fn=<AddBackward0>)
# 1 tensor([0.4197], grad_fn=<AddBackward0>)
# 0 tensor([0.7960], grad_fn=<AddBackward0>)
# 0 tensor([1.0141], grad_fn=<AddBackward0>)
# 0 tensor([1.0569], grad_fn=<AddBackward0>)
# 1 tensor([1.0869], grad_fn=<AddBackward0>)
# 0 tensor([0.9495], grad_fn=<AddBackward0>)
# 1 tensor([0.8335], grad_fn=<AddBackward0>)
# 1 tensor([0.7542], grad_fn=<AddBackward0>)
# 1 tensor([0.7200], grad_fn=<AddBackward0>)
# 1 tensor([0.7316], grad_fn=<AddBackward0>)
# 1 tensor([0.7828], grad_fn=<AddBackward0>)
# 0 tensor([0.7102], grad_fn=<AddBackward0>)
# 0 tensor([0.5373], grad_fn=<AddBackward0>)
# 0 tensor([0.3004], grad_fn=<AddBackward0>)
# 1 tensor([0.1931], grad_fn=<AddBackward0>)
# 0 tensor([0.0672], grad_fn=<AddBackward0>)
# 1 tensor([0.0952], grad_fn=<AddBackward0>)
# 0 tensor([0.1061], grad_fn=<AddBackward0>)
# 0 tensor([0.0997], grad_fn=<AddBackward0>)
# 1 tensor([0.2305], grad_fn=<AddBackward0>)
# 1 tensor([0.4647], grad_fn=<AddBackward0>)
# 1 tensor([0.7566], grad_fn=<AddBackward0>)
# 0 tensor([0.9047], grad_fn=<AddBackward0>)
# 0 tensor([0.9009], grad_fn=<AddBackward0>)
# 0 tensor([0.7611], grad_fn=<AddBackward0>)
# 1 tensor([0.6714], grad_fn=<AddBackward0>)
# 0 tensor([0.4890], grad_fn=<AddBackward0>)
# 1 tensor([0.4022], grad_fn=<AddBackward0>)
# 1 tensor([0.4146], grad_fn=<AddBackward0>)
# 0 tensor([0.3630], grad_fn=<AddBackward0>)
# 1 tensor([0.4130], grad_fn=<AddBackward0>)
# 1 tensor([0.5470], grad_fn=<AddBackward0>)
# 1 tensor([0.7363], grad_fn=<AddBackward0>)
# 0 tensor([0.7951], grad_fn=<AddBackward0>)
# 0 tensor([0.7274], grad_fn=<AddBackward0>)
# 0 tensor([0.5564], grad_fn=<AddBackward0>)
# 1 tensor([0.4696], grad_fn=<AddBackward0>)
# 0 tensor([0.3203], grad_fn=<AddBackward0>)
# 1 tensor([0.2889], grad_fn=<AddBackward0>)
# ------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# Input In [163], in <cell line: 1>()
#       5 avg_loss = 0
#       6 for s, a, r in sample:
# ----> 7     loss = DQNFull[action].backprop_single(s,a,r)
#       8     print(r, DQNFull[action](s))
#       9     avg_loss += loss
#
# Input In [134], in DQN.backprop_single(self, state, action, true_value)
#      13 mse_loss = (computed_value - true_value) ** 2
#      14 mse_loss.backward()
# ---> 15 self.optimizer.step()
#      16 return mse_loss.item()
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py:140, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     138 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139 with torch.autograd.profiler.record_function(profile_name):
# --> 140     out = func(*args, **kwargs)
#     141     obj._optimizer_step_code()
#     142     return out
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py:23, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      21 try:
#      22     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 23     ret = func(self, *args, **kwargs)
#      24 finally:
#      25     torch.set_grad_enabled(prev_grad)
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:234, in Adam.step(self, closure, grad_scaler)
#     231                 raise RuntimeError('`requires_grad` is not supported for `step` in differentiable mode')
#     232             state_steps.append(state['step'])
# --> 234     adam(params_with_grad,
#     235          grads,
#     236          exp_avgs,
#     237          exp_avg_sqs,
#     238          max_exp_avg_sqs,
#     239          state_steps,
#     240          amsgrad=group['amsgrad'],
#     241          beta1=beta1,
#     242          beta2=beta2,
#     243          lr=group['lr'],
#     244          weight_decay=group['weight_decay'],
#     245          eps=group['eps'],
#     246          maximize=group['maximize'],
#     247          foreach=group['foreach'],
#     248          capturable=group['capturable'],
#     249          differentiable=group['differentiable'],
#     250          fused=group['fused'],
#     251          grad_scale=grad_scale,
#     252          found_inf=found_inf)
#     254 return loss
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:300, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     297 else:
#     298     func = _single_tensor_adam
# --> 300 func(params,
#     301      grads,
#     302      exp_avgs,
#     303      exp_avg_sqs,
#     304      max_exp_avg_sqs,
#     305      state_steps,
#     306      amsgrad=amsgrad,
#     307      beta1=beta1,
#     308      beta2=beta2,
#     309      lr=lr,
#     310      weight_decay=weight_decay,
#     311      eps=eps,
#     312      maximize=maximize,
#     313      capturable=capturable,
#     314      differentiable=differentiable,
#     315      grad_scale=grad_scale,
#     316      found_inf=found_inf)
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:364, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     362 # Decay the first and second moment running average coefficient
#     363 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# --> 364 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     366 if capturable or differentiable:
#     367     step = step_t
#
# KeyboardInterrupt:

# %%
print(counts)
# Out:
# [[74969, 74974], [74777, 74786], [74851, 74861], [75247, 75257]]

# %%
for iteration in range(100):
    sample = random.sample(D, min(len(D),10000))
    avg_loss = 0
    for s, a, r in sample:
        loss = DQNetwork.backprop_single(s,a,r)
        avg_loss += loss
    avg_loss /= len(sample)
    print(avg_loss)
# Out:
# 1.0381510297510896
# 1.0080166441151295
# 1.009635012982856
# 1.0246107665729234
# 0.9912681942549865
# 1.0149562809613804
# 1.011351292843352
# 1.0231753498534022
# 0.9990903886910532
# 1.0956049033678235
# 0.9750692650138489
# 0.9610300931951852
# 0.9940751549784985
# 0.9631001674925337
# 1.0131517821022187
# 1.0895837585776291
# 0.9856074868755768
# 1.0294584598070455
# 1.0069715013987546
# ------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# Input In [158], in <cell line: 1>()
#       3 avg_loss = 0
#       4 for s, a, r in sample:
# ----> 5     loss = DQNetwork.backprop_single(s,a,r)
#       6     avg_loss += loss
#       7 avg_loss /= len(sample)
#
# Input In [134], in DQN.backprop_single(self, state, action, true_value)
#      13 mse_loss = (computed_value - true_value) ** 2
#      14 mse_loss.backward()
# ---> 15 self.optimizer.step()
#      16 return mse_loss.item()
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py:140, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     138 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     139 with torch.autograd.profiler.record_function(profile_name):
# --> 140     out = func(*args, **kwargs)
#     141     obj._optimizer_step_code()
#     142     return out
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/optimizer.py:23, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      21 try:
#      22     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 23     ret = func(self, *args, **kwargs)
#      24 finally:
#      25     torch.set_grad_enabled(prev_grad)
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:234, in Adam.step(self, closure, grad_scaler)
#     231                 raise RuntimeError('`requires_grad` is not supported for `step` in differentiable mode')
#     232             state_steps.append(state['step'])
# --> 234     adam(params_with_grad,
#     235          grads,
#     236          exp_avgs,
#     237          exp_avg_sqs,
#     238          max_exp_avg_sqs,
#     239          state_steps,
#     240          amsgrad=group['amsgrad'],
#     241          beta1=beta1,
#     242          beta2=beta2,
#     243          lr=group['lr'],
#     244          weight_decay=group['weight_decay'],
#     245          eps=group['eps'],
#     246          maximize=group['maximize'],
#     247          foreach=group['foreach'],
#     248          capturable=group['capturable'],
#     249          differentiable=group['differentiable'],
#     250          fused=group['fused'],
#     251          grad_scale=grad_scale,
#     252          found_inf=found_inf)
#     254 return loss
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:300, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     297 else:
#     298     func = _single_tensor_adam
# --> 300 func(params,
#     301      grads,
#     302      exp_avgs,
#     303      exp_avg_sqs,
#     304      max_exp_avg_sqs,
#     305      state_steps,
#     306      amsgrad=amsgrad,
#     307      beta1=beta1,
#     308      beta2=beta2,
#     309      lr=lr,
#     310      weight_decay=weight_decay,
#     311      eps=eps,
#     312      maximize=maximize,
#     313      capturable=capturable,
#     314      differentiable=differentiable,
#     315      grad_scale=grad_scale,
#     316      found_inf=found_inf)
#
# File /opt/anaconda3/lib/python3.8/site-packages/torch/optim/adam.py:363, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     360     param = torch.view_as_real(param)
#     362 # Decay the first and second moment running average coefficient
# --> 363 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     364 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     366 if capturable or differentiable:
#
# KeyboardInterrupt:
